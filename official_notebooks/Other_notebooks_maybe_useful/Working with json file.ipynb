# %%
import json
# Out:
# c:\users\gonza\tesisenv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# JSON file 
f = open ('json_file_merge.txt', "r") 
  
# Reading from file 
data = json.loads(f.read())
# Out:
# c:\users\gonza\tesisenv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data['relevantDocumentsDict_new']
# Out:
# c:\users\gonza\tesisenv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [{'0': 0.32864403719336244,
#   '1': 0.0808886074559624,
#   '2': 0.07215007215008161,
#   '3': 0.07218954416068951,
#   '4': 0.32864403719336244,
#   '5': 0.07914251730082758,
#   '6': 0.07215007215008161,
#   '7': 0.07823649103197788,
#   '8': 0.07229851425685374,
#   '9': 0.07215007215008161,
#   '10': 0.07215007215008161,
#   'text': '.\n#NYCACC\n#DogsOfTwitter\nMAYBACK #VID\n#ATTENTION\nEVERY1 WHOS INTERESTED IN\n#FOSTERING (for no costs to u) OR https://t.co/fogEzEdp4m'},
#  {'0': 0.3100961591057768,
#   '1': 0.08661796324570185,
#   '2': 0.0721500721502208,
#   '3': 0.0721500721502208,
#   '4': 0.3100961591057768,
#   '5': 0.07680160895748742,
#   '6': 0.07230599429859572,
#   '7': 0.0721500721502208,
#   '8': 0.0721500721502208,
#   '9': 0.0930664918932258,
#   '10': 0.07251149389832916,
#   'text': 'So, #Facebook. How are you? When are you going to reply to my numerous submitted help requests? Didnt you know it https://t.co/UJ92gKSVFd'},
#  {'0': 0.28967642526959203,
#   '1': 0.07704160246533778,
#   '2': 0.07704160246533778,
#   '3': 0.07704160246533778,
#   '4': 0.28967642526959203,
#   '5': 0.07704160246533778,
#   '6': 0.07704160246533778,
#   '7': 0.09399075500770566,
#   '8': 0.07704160246533778,
#   '9': 0.07704160246533778,
#   '10': 0.07704160246533778,
#   'text': "The horror when you realise you've only deactivated your Facebook account instead of deleting it and the mad panic https://t.co/m6RoP0BlA8"},
#  {'0': 0.2681401095771664,
#   '1': 0.07575757575758127,
#   '2': 0.09242424242424464,
#   '3': 0.07575757575758127,
#   '4': 0.2681401095771664,
#   '5': 0.07575757575758127,
#   '6': 0.07575757575758127,
#   '7': 0.10909090909089474,
#   '8': 0.07575757575758127,
#   '9': 0.07579043205297259,
#   '10': 0.0757664280668152,
#   'text': "If you send a message to Mark Zuckerberg or to any other Facebook executive, they'll keep a copy of it forever. But https://t.co/YvCSmYgJdi"},
#  {'0': 0.2638117745064796,
#   '1': 0.07451564828614209,
#   '2': 0.10719805523442971,
#   '3': 0.07451564828614209,
#   '4': 0.2638117745064796,
#   '5': 0.07451564828614209,
#   '6': 0.09097732570691448,
#   '7': 0.08124159347254675,
#   '8': 0.07451564828614209,
#   '9': 0.07532629848307035,
#   '10': 0.0833823594519908,
#   'text': 'As part of the GDPR / data protection regulations we want to make sure we only send marketing messages to those who https://t.co/5Erh0rkSAW'},
#  {'0': 0.2796969553355361,
#   '1': 0.07575757575759981,
#   '2': 0.07881766651039054,
#   '3': 0.07575757575759981,
#   '4': 0.2796969553355361,
#   '5': 0.07575757575759981,
#   '6': 0.07575757575759981,
#   '7': 0.09450441936243192,
#   '8': 0.07575757575759981,
#   '9': 0.09243550424604244,
#   '10': 0.07575757575759981,
#   'text': 'Steve Zebs privacy policy. \nBy excepting a friend request you agree to receive messages from Steve Zebs via Faceboo https://t.co/N6vrTwI8Au'},
#  {'0': 0.24415478791362916,
#   '1': 0.07451564828615065,
#   '2': 0.07451564828615065,
#   '3': 0.09090909090909582,
#   '4': 0.24415478791362916,
#   '5': 0.09090909090907977,
#   '6': 0.07451564828615065,
#   '7': 0.07451564828615065,
#   '8': 0.09090909090909163,
#   '9': 0.11053481823525163,
#   '10': 0.07452052797924921,
#   'text': '@FenauxRaphael @facebook Dont know this guy, accounts been hacked, but @facebook wont let me delete this account, https://t.co/o6Zgjh8HKw'},
#  {'0': 0.2515153779998892,
#   '1': 0.0826446280991829,
#   '2': 0.0826446280991829,
#   '3': 0.0826446280991829,
#   '4': 0.2515153779998892,
#   '5': 0.0826446280991829,
#   '6': 0.0826446280991829,
#   '7': 0.0826446280991829,
#   '8': 0.0826446280991829,
#   '9': 0.08667985321614087,
#   '10': 0.08329237208968972,
#   'text': 'Who cares! Look - Tom from MySpace is wearing different clothes!\n\nWHAT THE FUCK IS GOING ON PEOPLE? https://t.co/vPEq09LWhZ'},
#  {'0': 0.2641297437875425,
#   '1': 0.08057502717971433,
#   '2': 0.08802308802343525,
#   '3': 0.08485969001327809,
#   '4': 0.2641297437875425,
#   '5': 0.08483895592274543,
#   '6': 0.08802308802343568,
#   '7': 0.09022242394275166,
#   '8': 0.07246099600180773,
#   '9': 0.07471691495492971,
#   '10': 0.07215007215035953,
#   'text': "Will #Facebook's future look like the #Regulatory difficulties encountered by #Microsft in the past? \n\nIs GoogleBoo https://t.co/2sPBJXmNdm"},
#  {'0': 0.24110960232393835,
#   '1': 0.09087647642656249,
#   '2': 0.0745156482862055,
#   '3': 0.0745156482862055,
#   '4': 0.24110960232393835,
#   '5': 0.10730253353207854,
#   '6': 0.0745156482862055,
#   '7': 0.0745156482862055,
#   '8': 0.0745156482862055,
#   '9': 0.10787484828199144,
#   '10': 0.08025829800440164,
#   'text': 'I deleted my #Facebook account last week. It was painful to let go of something that was in my life for 10 years, i https://t.co/OZ2GUgdHSF'},
#  {'0': 0.2521346874476126,
#   '1': 0.08407452693437903,
#   '2': 0.08698031924523729,
#   '3': 0.07102272727321478,
#   '4': 0.2521346874476126,
#   '5': 0.07102272727321478,
#   '6': 0.07102272727321478,
#   '7': 0.08888833564025987,
#   '8': 0.13280849436643727,
#   '9': 0.07102272727321478,
#   '10': 0.07102272727321478,
#   'text': 'Just browsing through Facebook for a bit before bed: disabled man denied public transit, dog dead at groomer, dogs https://t.co/2jtQYk4hIC'},
#  {'0': 0.2596323869813355,
#   '1': 0.07837799029429342,
#   '2': 0.07836990595611693,
#   '3': 0.07836990595611693,
#   '4': 0.2596323869813355,
#   '5': 0.07839847530419389,
#   '6': 0.07836990595611693,
#   '7': 0.07836990595611693,
#   '8': 0.09585620059496158,
#   '9': 0.07836990595611693,
#   '10': 0.09588541704463097,
#   'text': "I am a young disabled person and I have decided to #DeleteFacebook- find out the reasons behind @emmavogelmann's https://t.co/VPSrN03yje"},
#  {'0': 0.3081380747244086,
#   '1': 0.08276797829044423,
#   '2': 0.06784260515611228,
#   '3': 0.06784260515611228,
#   '4': 0.3081380747244086,
#   '5': 0.08285912137887953,
#   '6': 0.06814374640840888,
#   '7': 0.08276797829040462,
#   '8': 0.0741019340146289,
#   '9': 0.06856323657098384,
#   '10': 0.09697272000961674,
#   'text': 'Log onto FB and first two posts on my timeline are about a court case were a man was caught drunk riding a horse an https://t.co/Q9EWBhkdLT'},
#  {'0': 0.24338986847234742,
#   '1': 0.08505033672964367,
#   '2': 0.08116883116890028,
#   '3': 0.08116883116890028,
#   '4': 0.24338986847234742,
#   '5': 0.08117576917819097,
#   '6': 0.08116883116890028,
#   '7': 0.08116883116890028,
#   '8': 0.08138313142120451,
#   '9': 0.10253218092315433,
#   '10': 0.08179338859985791,
#   'text': "What about people's accounts you disable for spurious reasons?\n@facebook #DeleteFacebook #facebookdisabled  https://t.co/PrSaCDCd5s"},
#  {'0': 0.22863097677808286,
#   '1': 0.13779357475516513,
#   '2': 0.06892114509926826,
#   '3': 0.06892148077245004,
#   '4': 0.22863097677808286,
#   '5': 0.06888968437750131,
#   '6': 0.0688705234162816,
#   '7': 0.0688705234162816,
#   '8': 0.08402203856770543,
#   '9': 0.07974522796396775,
#   '10': 0.125334824853296,
#   'text': '@DawkinsDog @facebook Michelle with a degree. Melania that cannot string a sentence together and plagiarized Michel https://t.co/neMO5VkvSz'},
#  {'0': 0.24241749763389575,
#   '1': 0.08417508417508607,
#   '2': 0.08417508417508607,
#   '3': 0.08417508417508607,
#   '4': 0.24241749763389575,
#   '5': 0.08417508417508607,
#   '6': 0.08417508417508607,
#   '7': 0.08417508417508607,
#   '8': 0.08417508417508607,
#   '9': 0.08417508417508607,
#   '10': 0.08418182896541576,
#   'text': 'Facebook secretly deleted messages Mark Zuckerberg sent on Messenger #privacy #dataprotection https://t.co/mBF79JNaBz'},
#  {'0': 0.22834230866671196,
#   '1': 0.07102272727276715,
#   '2': 0.08671077997059636,
#   '3': 0.08664772727277009,
#   '4': 0.22834230866671196,
#   '5': 0.07594037113500676,
#   '6': 0.07435528679429308,
#   '7': 0.08664772727274621,
#   '8': 0.07102272727276715,
#   '9': 0.12037017659132067,
#   '10': 0.09894016775102067,
#   'text': '@Ruksane @sku_dra Varbt di?\nQuickly delete multiple Facebook messages in Chrome\nInstead of deleting messages one https://t.co/UGtsE4mCUD'},
#  {'0': 0.24587248485064697,
#   '1': 0.08264462809917504,
#   '2': 0.08264462809917504,
#   '3': 0.08264462809917504,
#   '4': 0.24587248485064697,
#   '5': 0.08264462809917504,
#   '6': 0.08264462809917504,
#   '7': 0.08264462809917504,
#   '8': 0.08264462809917504,
#   '9': 0.09297049035595276,
#   '10': 0.08264462809917504,
#   'text': 'Surprise your man with 6-months of totally #FREE #AmazonPrimeVideo https://t.co/VdYOcKihmw  You = 6-months of https://t.co/oYPvGeUjqU'},
#  {'0': 0.24081016520322956,
#   '1': 0.09139194330997213,
#   '2': 0.08699106144187624,
#   '3': 0.11722140102945729,
#   '4': 0.24081016520322956,
#   '5': 0.07618773727337222,
#   '6': 0.07102272727273998,
#   '7': 0.08630439310360435,
#   '8': 0.07102272727273998,
#   '9': 0.07172379057708805,
#   '10': 0.08732405351592017,
#   'text': 'GSR did have one-time API access to a random sample of public tweets from a five-month period from December 2014 to https://t.co/T70D62rQZt'},
#  {'0': 0.226695937064048,
#   '1': 0.07575757575758285,
#   '2': 0.07575757575758285,
#   '3': 0.09242424242424635,
#   '4': 0.226695937064048,
#   '5': 0.10909090909090509,
#   '6': 0.08786439181093247,
#   '7': 0.08005218418557183,
#   '8': 0.07575757575758285,
#   '9': 0.09920380788907693,
#   '10': 0.0773958002624708,
#   'text': "Will the committee on 'screen use and young people's health' talk about the impact #CambridgeAnalytica had on young vulnerable people?"},
#  {'0': 0.229314810156581,
#   '1': 0.08116883116884482,
#   '2': 0.09901681576748722,
#   '3': 0.08116883116884482,
#   '4': 0.229314810156581,
#   '5': 0.08116883116884482,
#   '6': 0.08116883116884482,
#   '7': 0.08117798942734787,
#   '8': 0.08116883116884482,
#   '9': 0.10280550554651946,
#   '10': 0.08184072325784025,
#   'text': "Facebook bug secretly unblocked people you thought you'd blocked https://t.co/wmEl944CPS #Social #Facebook #Privacy"},
#  {'0': 0.22570532915349417,
#   '1': 0.07836990595612879,
#   '2': 0.07836990595612879,
#   '3': 0.07836990595612879,
#   '4': 0.22570532915349417,
#   '5': 0.09561128526647508,
#   '6': 0.07836990595612879,
#   '7': 0.11269985650878867,
#   '8': 0.07836990595612879,
#   '9': 0.09576409333446934,
#   '10': 0.07836990595612879,
#   'text': "At #DCMS, Schroepfer struggling to account for why Facebook discovered data breach from Kogan's app 3yrs ago and on https://t.co/7jxF4AHCFL"},
#  {'0': 0.22570532915344965,
#   '1': 0.07836990595612958,
#   '2': 0.09085631576830276,
#   '3': 0.08444821591255677,
#   '4': 0.22570532915344965,
#   '5': 0.07836990595612958,
#   '6': 0.07836990595612958,
#   '7': 0.09428794480822035,
#   '8': 0.07836990595612958,
#   '9': 0.09597031908265136,
#   '10': 0.09525225145030064,
#   'text': '@Manversusbike If you have every logged into anything via Facebook it has access to your world. Facebook app on pho https://t.co/BXe1uX0eGn'},
#  {'0': 0.22570532915475133,
#   '1': 0.07836990595652588,
#   '2': 0.09890909033111253,
#   '3': 0.07836990595652588,
#   '4': 0.22570532915475133,
#   '5': 0.07836990595652588,
#   '6': 0.07839235229824877,
#   '7': 0.1095324131715109,
#   '8': 0.07836990595652588,
#   '9': 0.09561128526174702,
#   '10': 0.07836990595652588,
#   'text': 'The amount of emails I have had on privacy policies is literally annoying! 30 unread emails thanks to that https://t.co/kQMIPKVMaT'},
#  {'0': 0.24145653102782694,
#   '1': 0.09090909090855541,
#   '2': 0.07451564828627215,
#   '3': 0.09316661213518218,
#   '4': 0.24145653102782694,
#   '5': 0.07451564828627215,
#   '6': 0.07489974951281468,
#   '7': 0.09813715366804095,
#   '8': 0.08251031265636471,
#   '9': 0.07882322079860232,
#   '10': 0.0910660327200685,
#   'text': 'Really ready to delete my Facebook. Hoes always on there pointing fingers like they shit dont stank. Dick riding asses'},
#  {'0': 0.24790860413540194,
#   '1': 0.07936814487200175,
#   '2': 0.06313131313147094,
#   '3': 0.09090909090919184,
#   '4': 0.24790860413540194,
#   '5': 0.06313131313147094,
#   '6': 0.06313131313147094,
#   '7': 0.0829893110142466,
#   '8': 0.07259481854409486,
#   '9': 0.13229229550616842,
#   '10': 0.10454379562448185,
#   'text': 'The algorithmically enhanced #Facebook timeline acts indirectly on your social graph, in two ways: \n* hiding so https://t.co/H1fAhFsdXh'},
#  {'0': 0.22187981510018545,
#   '1': 0.09101175397933857,
#   '2': 0.07704160246537749,
#   '3': 0.07704160246537749,
#   '4': 0.22187981510018545,
#   '5': 0.07704160246537749,
#   '6': 0.07704160246537749,
#   '7': 0.07704160246537749,
#   '8': 0.0772153738900711,
#   '9': 0.07704160246537749,
#   '10': 0.14764344223814005,
#   'text': 'https://t.co/s8jrc56hAL Welllllllll not even surprised at all tbh. :|\n\nI mean literally jack could be killing toddl https://t.co/3txwxOVBvU'},
#  {'0': 0.23068370281015488,
#   '1': 0.0939907550075095,
#   '2': 0.08284089157938662,
#   '3': 0.07704160246574256,
#   '4': 0.23068370281015488,
#   '5': 0.09598077125564043,
#   '6': 0.07704160246574256,
#   '7': 0.07707044738174192,
#   '8': 0.11126702210259651,
#   '9': 0.07704160246574256,
#   '10': 0.07704160246574256,
#   'text': "If I was Mr. Zuckerberg, I'd be looking at a halving of my share price in the next couple of years, basically. https://t.co/1UfblAG35x"},
#  {'0': 0.23467552050068724,
#   '1': 0.10312789985745932,
#   '2': 0.09236417133100121,
#   '3': 0.08072377166615372,
#   '4': 0.23467552050068724,
#   '5': 0.0757575757576045,
#   '6': 0.09270901043558906,
#   '7': 0.0757575757576045,
#   '8': 0.07579458346972427,
#   '9': 0.09248431351754403,
#   '10': 0.07660557770663207,
#   'text': 'Are you telling me that China, a country of billionaires, where the private economy accounts for 80% of all jobs, w https://t.co/vXsz4SlVoJ'},
#  {'0': 0.2278545730166766,
#   '1': 0.08576329331046563,
#   '2': 0.08576329331046563,
#   '3': 0.08576329331046563,
#   '4': 0.2278545730166766,
#   '5': 0.08576329331046563,
#   '6': 0.08576329331046563,
#   '7': 0.08576329331046563,
#   '8': 0.08603908049959827,
#   '9': 0.08576329331046563,
#   '10': 0.08576329331046563,
#   'text': 'Facebook account has been permanently deleted.  Goodbye Facebook #DeleteFacebook'},
#  {'0': 0.22159346564385995,
#   '1': 0.07974481658694565,
#   '2': 0.07974481658694565,
#   '3': 0.0798402909306003,
#   '4': 0.22159346564385995,
#   '5': 0.09695526653569962,
#   '6': 0.07974481658694565,
#   '7': 0.08007822628729207,
#   '8': 0.07974481658694565,
#   '9': 0.12216678148464376,
#   '10': 0.08038670277012162,
#   'text': 'The number of people searching how to delete Facebook online doubled in March - with Londoners most likely to wan https://t.co/LKAnAb820L'},
#  {'0': 0.2263462739474345,
#   '1': 0.07654195981132465,
#   '2': 0.09241257332612968,
#   '3': 0.08441100345424954,
#   '4': 0.2263462739474345,
#   '5': 0.08563095793834413,
#   '6': 0.08377081472506478,
#   '7': 0.10051290662706182,
#   '8': 0.08211516824477394,
#   '9': 0.07575757575783834,
#   '10': 0.09250076616777857,
#   'text': 'Germans and their privacy-oriented super mysterious Facebook aliases. getting friend requests like who tf is this p https://t.co/WQmUtfAj11'},
#  {'0': 0.21656698051471113,
#   '1': 0.10504119534772056,
#   '2': 0.09242424242479075,
#   '3': 0.09242424242412425,
#   '4': 0.21656698051471113,
#   '5': 0.07575757575802794,
#   '6': 0.09242424242479298,
#   '7': 0.07575757575802794,
#   '8': 0.09242424241958765,
#   '9': 0.07679978989194389,
#   '10': 0.080379913036273,
#   'text': "@wef Honestly, I couldn't care less about #Zuckerberg's staggeringly late realizations.\n\n#DeleteYourFacebookAccount https://t.co/nFVrePdlN6"},
#  {'0': 0.23320573476769457,
#   '1': 0.07705969445288681,
#   '2': 0.09242424242423104,
#   '3': 0.07576475441618269,
#   '4': 0.23320573476769457,
#   '5': 0.0924509604973509,
#   '6': 0.10908373043234414,
#   '7': 0.07575757575759741,
#   '8': 0.07604037978329939,
#   '9': 0.09245535171081554,
#   '10': 0.07575757575759741,
#   'text': 'Safer alternatives to Facebook ! \nhttps://t.co/XRmMKCg5lY\n\nFind me on Minds, may be on others later.  https://t.co/0FYQZwdM7B'},
#  {'0': 0.22189036849480492,
#   '1': 0.08116883116883242,
#   '2': 0.1106889529268781,
#   '3': 0.08681074472587139,
#   '4': 0.22189036849480492,
#   '5': 0.0880039290474799,
#   '6': 0.08116883116883242,
#   '7': 0.0817210815680322,
#   '8': 0.08116883116883242,
#   '9': 0.08547950673300596,
#   '10': 0.0818989229974302,
#   'text': 'I logged into Facebook for the first time in a month and saw people that thought typing BFF is an indicator of th https://t.co/wqQbZsruMN'},
#  {'0': 0.25107003110344234,
#   '1': 0.0797086372349516,
#   '2': 0.0956112852664552,
#   '3': 0.07836990595611683,
#   '4': 0.25107003110344234,
#   '5': 0.08614923134811012,
#   '6': 0.07836990595611683,
#   '7': 0.07836990595611683,
#   '8': 0.0956112852664566,
#   '9': 0.07836990595611683,
#   '10': 0.07836990595611683,
#   'text': '@mikko @vornaskotti @5ean5ullivan Actually you can delete your facebook account (not just deactivate it)\nI found th https://t.co/uyYMARfQaZ'},
#  {'0': 0.22107244739569548,
#   '1': 0.13290396488131392,
#   '2': 0.08160815493055429,
#   '3': 0.06937402307509156,
#   '4': 0.22107244739569548,
#   '5': 0.08666453449049161,
#   '6': 0.0668449197865648,
#   '7': 0.08503649137768232,
#   '8': 0.11896055474405356,
#   '9': 0.07068998953198777,
#   '10': 0.0668449197865648,
#   'text': '@TomLondon6 Cambridge Analytica scandal and brexit are both evidence of an attempt to end democracy, the privatizat https://t.co/dkOxN0VP3r'},
#  {'0': 0.23262421722287224,
#   '1': 0.0770416024653369,
#   '2': 0.0770416024653369,
#   '3': 0.0770416024653369,
#   '4': 0.23262421722287224,
#   '5': 0.0770416024653369,
#   '6': 0.0770416024653369,
#   '7': 0.09484582150201155,
#   '8': 0.11021293912883673,
#   '9': 0.0770416024653369,
#   '10': 0.10006740735425815,
#   'text': 'You know when someone takes your nice well-meaning idea in a meeting and turns it into something shit and adds load https://t.co/NxlSpOcyBt'},
#  {'0': 0.22038683296272915,
#   '1': 0.08264462809918348,
#   '2': 0.08264462809918348,
#   '3': 0.08264462809918348,
#   '4': 0.22038683296272915,
#   '5': 0.10082644628089607,
#   '6': 0.08264462809918348,
#   '7': 0.08264462809918348,
#   '8': 0.09199408228160143,
#   '9': 0.08315794706609299,
#   '10': 0.090411550912763,
#   'text': 'Final Facebook is off my phone, and my battery life is already lasting longer :)\n\n#DeleteFacebook'},
#  {'0': 0.21983471074377975,
#   '1': 0.08264462809917685,
#   '2': 0.10080247562767748,
#   '3': 0.08264462809917685,
#   '4': 0.21983471074377975,
#   '5': 0.08264462809917685,
#   '6': 0.08264462809917685,
#   '7': 0.08264462809917685,
#   '8': 0.08264462809917685,
#   '9': 0.1008504169343049,
#   '10': 0.08264462809917685,
#   'text': "#samsung why can't I delete Facebook permanently from my S8 phone? Stop forcing Facebook on me! Let us Delete this https://t.co/ajKNC0QdAb"},
#  {'0': 0.24766667640785867,
#   '1': 0.07046526584088836,
#   '2': 0.11096256684436948,
#   '3': 0.09098419951735166,
#   '4': 0.24766667640785867,
#   '5': 0.06684491978615353,
#   '6': 0.06687508574058472,
#   '7': 0.08020251094718836,
#   '8': 0.12566844919789766,
#   '9': 0.07213711473964951,
#   '10': 0.06819321097805806,
#   'text': 'Through #Facebook you can upload a list of emails of specific users, for instance newsletter subscribers or sign up https://t.co/FEZgdRxmY7'},
#  {'0': 0.22147583151188757,
#   '1': 0.08264462809919691,
#   '2': 0.08264462809919691,
#   '3': 0.08264462809919691,
#   '4': 0.22147583151188757,
#   '5': 0.08264462809919691,
#   '6': 0.08264462809919691,
#   '7': 0.08264462809919691,
#   '8': 0.11589941905872646,
#   '9': 0.08264462809919691,
#   '10': 0.08411235273500763,
#   'text': 'Zuckerberg wasnt being honest about being dishonest. Color me surprised  \n\n#DeleteFacebook https://t.co/gsrtM7Duus'},
#  {'0': 0.21649793047960153,
#   '1': 0.08116883116894404,
#   '2': 0.09194915071654923,
#   '3': 0.08761989001381751,
#   '4': 0.21649793047960153,
#   '5': 0.09268310473172972,
#   '6': 0.08116883116894404,
#   '7': 0.08179459563363282,
#   '8': 0.09908195921826381,
#   '9': 0.08594691492831834,
#   '10': 0.08208879194019904,
#   'text': 'Do people actually care about how much data hovers up about them https://t.co/2J0mLiiyU7. Cause it scares the shit out of me.'},
#  {'0': 0.2194293523235164,
#   '1': 0.08417508417524783,
#   '2': 0.08417508417524783,
#   '3': 0.08417508417524783,
#   '4': 0.2194293523235164,
#   '5': 0.10269360269186069,
#   '6': 0.08417508417524783,
#   '7': 0.08417508417524783,
#   '8': 0.08417508417524783,
#   '9': 0.08784359618492206,
#   '10': 0.0849829437482138,
#   'text': 'Encase people do not know, I deleted my #Facebook account almost a https://t.co/PaGPURgwwZ'},
#  {'0': 0.21590909090908184,
#   '1': 0.08116883116883343,
#   '2': 0.09901014901180619,
#   '3': 0.09531631186277535,
#   '4': 0.21590909090908184,
#   '5': 0.08116883116883343,
#   '6': 0.09902597402597317,
#   '7': 0.08116883116883343,
#   '8': 0.08116883116883343,
#   '9': 0.08118465618299828,
#   '10': 0.08487849333203142,
#   'text': 'Facebook can still track you even after you delete your account | Daily Mail Online https://t.co/ZOldRJsECm via @pinterest'},
#  {'0': 0.21590909090906799,
#   '1': 0.09899325174618298,
#   '2': 0.08606380473271201,
#   '3': 0.08315441601523814,
#   '4': 0.21590909090906799,
#   '5': 0.08116883116886367,
#   '6': 0.08116883116886367,
#   '7': 0.09214541561578982,
#   '8': 0.09902597402573554,
#   '9': 0.08116883116886367,
#   '10': 0.08120155344868256,
#   'text': 'Us too. Or stripped the account of data and connections as we still authenticate elsewhere with it for now. Faceboo https://t.co/13qdmMNlVA'},
#  {'0': 0.2255707963004654,
#   '1': 0.09036167816600196,
#   '2': 0.08116883116883433,
#   '3': 0.08116883116883433,
#   '4': 0.2255707963004654,
#   '5': 0.08116883116883433,
#   '6': 0.08116883116883433,
#   '7': 0.08883375789388079,
#   '8': 0.0990259740259591,
#   '9': 0.08983312702880722,
#   '10': 0.0816993419095482,
#   'text': '.@zeynep on the money again &gt; Why Zuckerbergs 14-Year Apology Tour Hasnt Fixed Facebook https://t.co/1YVrs4A70W via @WIRED'},
#  {'0': 0.21677097619395952,
#   '1': 0.08842331979732809,
#   '2': 0.09381483598906384,
#   '3': 0.07102272727344097,
#   '4': 0.21677097619395952,
#   '5': 0.09066745211834822,
#   '6': 0.07102272727344097,
#   '7': 0.11762970463826011,
#   '8': 0.0866477272735816,
#   '9': 0.07727102037765961,
#   '10': 0.08672950906491701,
#   'text': "I'm still waiting for the link to #CambridgeAnalytica when the #Skirpals finally give public testimony...which they https://t.co/rMmY97rjxR"},
#  {'0': 0.2051512384910799,
#   '1': 0.07332266686867007,
#   '2': 0.10549426291769559,
#   '3': 0.08944281524930388,
#   '4': 0.2051512384910799,
#   '5': 0.0803447453117288,
#   '6': 0.07331378299124491,
#   '7': 0.08948139467614889,
#   '8': 0.08948182041212895,
#   '9': 0.10557184750738324,
#   '10': 0.08839542557461574,
#   'text': 'Geolocation is just one tool in this armoury, and a great way to ensure  you are delivering the right message to t https://t.co/QLWvFD8o6H'},
#  {'0': 0.21383069927196038,
#   '1': 0.10003562501984503,
#   '2': 0.08264462809919931,
#   '3': 0.08343544936008918,
#   '4': 0.21383069927196038,
#   '5': 0.10080258438264508,
#   '6': 0.08266848999756798,
#   '7': 0.08264462809919931,
#   '8': 0.08264462809919931,
#   '9': 0.08264462809919931,
#   '10': 0.08864863957109496,
#   'text': 'Facebook Conference (F8) feels like a joke every year, specially after Cambridge Analytica.'},
#  {'0': 0.2615220915048774,
#   '1': 0.15281668530034556,
#   '2': 0.08812945323879533,
#   '3': 0.07438059444968276,
#   '4': 0.2615220915048774,
#   '5': 0.08036890645587894,
#   '6': 0.0658761528326943,
#   '7': 0.07002791935023911,
#   '8': 0.06589214210401961,
#   '9': 0.06912158992459726,
#   '10': 0.07186446483886995,
#   'text': 'FACT CHECK: Is Facebook Removing the Share Button from Pro-Trump Posts? https://t.co/zeiv0eZM3K As usual, Senator T https://t.co/Oq5Ap6nWdn'},
#  {'0': 0.21542237822501797,
#   '1': 0.08417508417508897,
#   '2': 0.08417508417508897,
#   '3': 0.08417508417508897,
#   '4': 0.21542237822501797,
#   '5': 0.08417508417508897,
#   '6': 0.08417508417508897,
#   '7': 0.08417508417508897,
#   '8': 0.10238083368216301,
#   '9': 0.08471824326731386,
#   '10': 0.09242803977497126,
#   'text': "Delete your curious cat account (or not) it's your life not mine https://t.co/qskdxDD93s"},
#  {'0': 0.2065073802516426,
#   '1': 0.10923597348657745,
#   '2': 0.07575757575791509,
#   '3': 0.07584230848602215,
#   '4': 0.2065073802516426,
#   '5': 0.07575962611276282,
#   '6': 0.08319164987927813,
#   '7': 0.07828523952785224,
#   '8': 0.10908677280106488,
#   '9': 0.09256325015856852,
#   '10': 0.09377022353831611,
#   'text': "@withorpe @June4th Either the gov't, is plain fuking stupid or they must get a net return from taxing the people wh https://t.co/VZYP5HMNuS"},
#  {'0': 0.2337043007201033,
#   '1': 0.06493506493515583,
#   '2': 0.07799587981220982,
#   '3': 0.08033675253079042,
#   '4': 0.2337043007201033,
#   '5': 0.06671778120878809,
#   '6': 0.06493506493515583,
#   '7': 0.06984100792478479,
#   '8': 0.07995555234966159,
#   '9': 0.12584683719151432,
#   '10': 0.13573175839183607,
#   'text': 'Very  interesting interview and basically agree with his points . For me Facebook is the worst social media out the https://t.co/YR3rJlZd7L'},
#  {'0': 0.21980845450416017,
#   '1': 0.09556419494991604,
#   '2': 0.08426678060549118,
#   '3': 0.07836990595612472,
#   '4': 0.21980845450416017,
#   '5': 0.07885581509942528,
#   '6': 0.07836990595612472,
#   '7': 0.08536852970827942,
#   '8': 0.09565837558300218,
#   '9': 0.09617080167846366,
#   '10': 0.08756723595901256,
#   'text': 'My aunt and uncle deleted me on Facebook and made my cousins delete me because I shared something pro choice lol'},
#  {'0': 0.22570532915352087,
#   '1': 0.09561128526646864,
#   '2': 0.07836990595613116,
#   '3': 0.07836990595613116,
#   '4': 0.22570532915352087,
#   '5': 0.11285266457677506,
#   '6': 0.07836990595613116,
#   '7': 0.07836990595613116,
#   '8': 0.09561128526644842,
#   '9': 0.07836990595613116,
#   '10': 0.07836990595613116,
#   'text': "@simple_season There's a protest when he's visiting the UK 12th-13th-14th July, with coaches going from all over th https://t.co/PtSti7QNAX"},
#  {'0': 0.21823711617563357,
#   '1': 0.07836990595611476,
#   '2': 0.14730944268301163,
#   '3': 0.07836990595611476,
#   '4': 0.21823711617563357,
#   '5': 0.07836990595611476,
#   '6': 0.07836990595611476,
#   '7': 0.08577279941661596,
#   '8': 0.07836990595611476,
#   '9': 0.0783794998394147,
#   '10': 0.07845161210475031,
#   'text': "So finally Facebook admits tracking users, even if they're logged out or dont even have a Facebook account\nhttps://t.co/k0kbu9GnD8 #privacy"},
#  {'0': 0.20821272721518647,
#   '1': 0.11285266457651516,
#   '2': 0.09561128526148174,
#   '3': 0.07836990595663905,
#   '4': 0.20821272721518647,
#   '5': 0.07836990595663905,
#   '6': 0.07836990595663905,
#   '7': 0.07836990595663905,
#   '8': 0.07862112858606422,
#   '9': 0.0960405876177368,
#   '10': 0.09518198291645938,
#   'text': "Facts! Let's stop pretending Toby Maguire was any good and permanently delete Spiderman 2 and 3 - Derek https://t.co/ikS2Hi3hDT"},
#  {'0': 0.20699442176272306,
#   '1': 0.07983943403677346,
#   '2': 0.15938471520365416,
#   '3': 0.07836990595615906,
#   '4': 0.20699442176272306,
#   '5': 0.07836990595615906,
#   '6': 0.07836990595615906,
#   '7': 0.07836990595615906,
#   '8': 0.08349363937432809,
#   '9': 0.07843825984172582,
#   '10': 0.07836990595615906,
#   'text': 'BBC News - Facebook seeks facial recognition consent in EU and Canada https://t.co/RiqhaRhF7a &gt;DELETE YOUR ACCOUNT https://t.co/XryuqR4Qaz'},
#  {'0': 0.22022382608963026,
#   '1': 0.09985886491426976,
#   '2': 0.06887717840578032,
#   '3': 0.0688705234167734,
#   '4': 0.22022382608963026,
#   '5': 0.09059998672077155,
#   '6': 0.0688705234167734,
#   '7': 0.11547495310323706,
#   '8': 0.11432506887163904,
#   '9': 0.06887703649291443,
#   '10': 0.08402203856821074,
#   'text': 'I have just contacted #yahoo to complain about the spectacularly intensive advertising campaign they are running vi https://t.co/BrmItu9ner'},
#  {'0': 0.19938647259815573,
#   '1': 0.14311300320130316,
#   '2': 0.07102272727274543,
#   '3': 0.07363125457243164,
#   '4': 0.19938647259815573,
#   '5': 0.09961192271399569,
#   '6': 0.07102272727274543,
#   '7': 0.07165322692348136,
#   '8': 0.10229176320070843,
#   '9': 0.09640784833879931,
#   '10': 0.07185905390563374,
#   'text': '@bloonface @dewordepolitics @clfinnecy @loftandlost @BradipoWayway @Bi99le5 added to this he could talk about Cambr https://t.co/tsOIIutcKA'},
#  {'0': 0.21005698508849827,
#   '1': 0.0839187722914626,
#   '2': 0.07451564828616065,
#   '3': 0.09090909090911506,
#   '4': 0.21005698508849827,
#   '5': 0.11702108416227101,
#   '6': 0.07452176353105347,
#   '7': 0.07451564828616065,
#   '8': 0.07451564828616065,
#   '9': 0.1094604659895654,
#   '10': 0.09056489316955227,
#   'text': "So, today is a big day for me  \n\nYes, I'm quitting #Facebook. No one ever bothers to speak to me on there anyway s https://t.co/nWptNalKqe"},
#  {'0': 0.21300659621873982,
#   '1': 0.08664772727314825,
#   '2': 0.10915715249405519,
#   '3': 0.07102272727308313,
#   '4': 0.21300659621873982,
#   '5': 0.09501647860523067,
#   '6': 0.07111561726748938,
#   '7': 0.0711289470556433,
#   '8': 0.10220066762791284,
#   '9': 0.09418340904325126,
#   '10': 0.08652067714144611,
#   'text': 'I must say, since I deleted #Facebook and deactivated my account it has given me more time to myself. Previously ha https://t.co/lSTcUHsspF'},
#  {'0': 0.20667127267394741,
#   '1': 0.10342851507622958,
#   '2': 0.07974481658699126,
#   '3': 0.07974481658699126,
#   '4': 0.20667127267394741,
#   '5': 0.07974481658699126,
#   '6': 0.07974481658699126,
#   '7': 0.07975580904085446,
#   '8': 0.09728867623601009,
#   '9': 0.11413164403800213,
#   '10': 0.07974481658699126,
#   'text': 'My #colleague left his #Facebook signed in on my browser so I took the liberty of #reading his messages for him . https://t.co/ZOc2IuDtvl'},
#  {'0': 0.22558917057196354,
#   '1': 0.0811688311688422,
#   '2': 0.0811688311688422,
#   '3': 0.08168336652104873,
#   '4': 0.22558917057196354,
#   '5': 0.0811688311688422,
#   '6': 0.09851143867377718,
#   '7': 0.0811802449005134,
#   '8': 0.0811688311688422,
#   '9': 0.0992928969616426,
#   '10': 0.0890675576956858,
#   'text': "Doesn't look like my Facebook date was used as I'm assured neither me nor my FB friends logged into My Digital Life https://t.co/4RCVwe5sY4"},
#  {'0': 0.2132867132831656,
#   '1': 0.08741258741298158,
#   '2': 0.08741258741298158,
#   '3': 0.08741258741298158,
#   '4': 0.2132867132831656,
#   '5': 0.08741258741298158,
#   '6': 0.08741258741298158,
#   '7': 0.08741258741298158,
#   '8': 0.08741258741298158,
#   '9': 0.08741258741298158,
#   '10': 0.08741258741298158,
#   'text': 'Senator Hatch is a better lobbyist for Mark Zuckerberg than Mark Zuckerberg. There are always tradeoffs.'},
#  {'0': 0.2099769416931157,
#   '1': 0.0841750841750856,
#   '2': 0.0841750841750856,
#   '3': 0.0841750841750856,
#   '4': 0.2099769416931157,
#   '5': 0.0841750841750856,
#   '6': 0.08421544022887795,
#   '7': 0.0841750841750856,
#   '8': 0.08447714323982101,
#   '9': 0.11548231129809788,
#   '10': 0.0849727426646595,
#   'text': 'These people are simply not to be trusted https://t.co/KiFHpXL0cG #DeleteFacebook'},
#  {'0': 0.21317924586548348,
#   '1': 0.08741258741259125,
#   '2': 0.08752005483378641,
#   '3': 0.08741258741259125,
#   '4': 0.21317924586548348,
#   '5': 0.08741258741259125,
#   '6': 0.08741258741259125,
#   '7': 0.08741258741259125,
#   '8': 0.08741258741259125,
#   '9': 0.08741258741259125,
#   '10': 0.08741258741259125,
#   'text': 'WAIT WHAT ABOUT THE T-SHIRT https://t.co/jPbxLKpFfC'},
#  {'0': 0.22464430524535894,
#   '1': 0.09902597402597627,
#   '2': 0.0990259740259767,
#   '3': 0.0811688311688361,
#   '4': 0.22464430524535894,
#   '5': 0.08990977250430346,
#   '6': 0.0811688311688361,
#   '7': 0.0811688311688361,
#   '8': 0.0811688311688361,
#   '9': 0.08154981835420405,
#   '10': 0.0811688311688361,
#   'text': '@rapplerdotcom as @facebooks fact checker? #Rappler needs fact checking itself. But well, if that day comes, Ill https://t.co/aj0sUpqOC3'},
#  {'0': 0.21302388886741797,
#   '1': 0.08741258741258956,
#   '2': 0.08741258741258956,
#   '3': 0.08741258741258956,
#   '4': 0.21302388886741797,
#   '5': 0.08741258741258956,
#   '6': 0.08741258741258956,
#   '7': 0.08741258741258956,
#   '8': 0.08746926409003522,
#   '9': 0.08741258741258956,
#   '10': 0.0876187351544198,
#   'text': "I bet he's shitting himself https://t.co/mDEjmvkeO3"},
#  {'0': 0.20534851483377692,
#   '1': 0.08109415735113944,
#   '2': 0.08142141678651249,
#   '3': 0.08234385145645477,
#   '4': 0.20534851483377692,
#   '5': 0.08607610372831362,
#   '6': 0.07974481658693389,
#   '7': 0.1041933367778512,
#   '8': 0.07974481658693389,
#   '9': 0.10274430965602988,
#   '10': 0.0972886762360539,
#   'text': 'Mr. Zuckerberg...if I forget my wifi password, can I just restart it to set a new one? Or do I have to call the cab https://t.co/EOLaZxRpju'},
#  {'0': 0.21107272134220478,
#   '1': 0.08963813303026474,
#   '2': 0.08005165220781732,
#   '3': 0.0809002683640757,
#   '4': 0.21107272134220478,
#   '5': 0.07836990595647426,
#   '6': 0.1027007347224303,
#   '7': 0.1034856520016638,
#   '8': 0.0970411204621207,
#   '9': 0.07836990595647426,
#   '10': 0.07836990595647426,
#   'text': 'No he doesnt. A suitably senior and qualified representative of the company should suffice, unless you are interes https://t.co/T8qKSUfqNm'},
#  {'0': 0.20356349915779917,
#   '1': 0.09728867623639492,
#   '2': 0.07974481658731399,
#   '3': 0.07974481658731399,
#   '4': 0.20356349915779917,
#   '5': 0.07974481658731399,
#   '6': 0.07974481658731399,
#   '7': 0.08802782748190673,
#   '8': 0.08001951865676998,
#   '9': 0.09728867623649363,
#   '10': 0.1148325358813796,
#   'text': '#DeleteFacebook everybody. Seriously #DeleteFacebookNow\n\n+\nDoes #fakebook indirectly contribute to #suicide and https://t.co/jox1uJkWd3'},
#  {'0': 0.198246163963297,
#   '1': 0.07472362812615481,
#   '2': 0.09087455138703168,
#   '3': 0.09098897884444994,
#   '4': 0.198246163963297,
#   '5': 0.08011679309414424,
#   '6': 0.07451564828617191,
#   '7': 0.1179257666465282,
#   '8': 0.07451564828617191,
#   '9': 0.10713919239303853,
#   '10': 0.09095362897301183,
#   'text': '#Facebook was warned by security researchers that attackers could abuse its phone number and email search facility https://t.co/pCsEPIeiVi'},
#  {'0': 0.19844501233000936,
#   '1': 0.07836368486679672,
#   '2': 0.09090909090948189,
#   '3': 0.11249225371116908,
#   '4': 0.19844501233000936,
#   '5': 0.09705577963405745,
#   '6': 0.10187942546151023,
#   '7': 0.0847624021848961,
#   '8': 0.07451564828646529,
#   '9': 0.07451564828646529,
#   '10': 0.08706105432914862,
#   'text': 'Downplaying the number of accounts affected by Cambridge Analytica by mentioning only the first degree accounts :  https://t.co/54UgpYti5u'},
#  {'0': 0.20926243567753086,
#   '1': 0.0857632933104661,
#   '2': 0.0857632933104661,
#   '3': 0.0857632933104661,
#   '4': 0.20926243567753086,
#   '5': 0.0858449346441963,
#   '6': 0.0857632933104661,
#   '7': 0.10454957650501003,
#   '8': 0.0857632933104661,
#   '9': 0.0857632933104661,
#   '10': 0.0857632933104661,
#   'text': "Mark Zuckerberg says it'll take three years to 'fix' Facebook - CNET  https://t.co/Mfh45RFa5u"},
#  {'0': 0.20926243567752542,
#   '1': 0.0857632933104642,
#   '2': 0.0857632933104642,
#   '3': 0.0857632933104642,
#   '4': 0.20926243567752542,
#   '5': 0.0857632933104642,
#   '6': 0.0857632933104642,
#   '7': 0.0857632933104642,
#   '8': 0.0857632933104642,
#   '9': 0.1046312178387608,
#   '10': 0.0857632933104642,
#   'text': '#Facebook is shutting down a teen app it bought eight months ago https://t.co/kogEDUE7E4'},
#  {'0': 0.20926243567752767,
#   '1': 0.08576329331048375,
#   '2': 0.08627360420366278,
#   '3': 0.08576329331048375,
#   '4': 0.20926243567752767,
#   '5': 0.0937259144327761,
#   '6': 0.08576329331048375,
#   '7': 0.09615828582313088,
#   '8': 0.08576329331048375,
#   '9': 0.08576329331048375,
#   '10': 0.08576329331048375,
#   'text': "Fucking Hina, trying to negotiate my cat's account. Bitch, we're taking this to Mark Zuckerberg https://t.co/yMUcltxCF1"},
#  {'0': 0.20926243567505481,
#   '1': 0.08576329331129227,
#   '2': 0.08576329331129227,
#   '3': 0.08576329331129227,
#   '4': 0.20926243567505481,
#   '5': 0.08576329331129227,
#   '6': 0.08576329331129227,
#   '7': 0.08576329331129227,
#   '8': 0.08576329331129227,
#   '9': 0.08576329331129227,
#   '10': 0.1046312178346069,
#   'text': '#DeleteFacebook if you dare. You can! Sehr lesenswerter Artikel. @greiten  https://t.co/3bzlBN7lHt'},
#  {'0': 0.20924925180862122,
#   '1': 0.08577647717970875,
#   '2': 0.08576329331056358,
#   '3': 0.08576329331056358,
#   '4': 0.20924925180862122,
#   '5': 0.08576329331056358,
#   '6': 0.08576329331056358,
#   '7': 0.08576329331056358,
#   '8': 0.08576329331056358,
#   '9': 0.10463121783772499,
#   '10': 0.08576329331056358,
#   'text': "After all man means person really, right? #everydaysexism #bbcnews - Zuckerberg: I'm still the man to run Facebook https://t.co/AZEFUWtiLW"},
#  {'0': 0.20923249397444804,
#   '1': 0.08576329331046978,
#   '2': 0.08576329331046978,
#   '3': 0.08576329331046978,
#   '4': 0.20923249397444804,
#   '5': 0.08576607317458647,
#   '6': 0.08576584160049174,
#   '7': 0.08576329331046978,
#   '8': 0.10462588968463349,
#   '9': 0.08576329331046978,
#   '10': 0.08579323501349136,
#   'text': 'https://t.co/hPVdDoxDNk apparently, Facebook should be broken up - erm, how would that work?'},
#  {'0': 0.21328671328669796,
#   '1': 0.0874125874125891,
#   '2': 0.0874125874125891,
#   '3': 0.0874125874125891,
#   '4': 0.21328671328669796,
#   '5': 0.0874125874125891,
#   '6': 0.0874125874125891,
#   '7': 0.0874125874125891,
#   '8': 0.0874125874125891,
#   '9': 0.0874125874125891,
#   '10': 0.0874125874125891,
#   'text': '#Zuckerberg reminds me of Titians Vandramin Family @gleniculate https://t.co/jxIJXIVS1L'},
#  {'0': 0.250491992120373,
#   '1': 0.07575757575760929,
#   '2': 0.08741643936472777,
#   '3': 0.07982125602410434,
#   '4': 0.250491992120373,
#   '5': 0.09558698757668116,
#   '6': 0.09078620582945081,
#   '7': 0.08568910914941984,
#   '8': 0.07575757575760929,
#   '9': 0.08292820516006277,
#   '10': 0.07576465325996162,
#   'text': '@rachelcoldicutt I can give refugees data top-ups for their phones via a Facebook group, so they can talk to their https://t.co/vl8rJ13mba'},
#  {'0': 0.23531481819962152,
#   '1': 0.07836990595614703,
#   '2': 0.07836990595614703,
#   '3': 0.07919772803224204,
#   '4': 0.23531481819962152,
#   '5': 0.11680415292158816,
#   '6': 0.07836990595614703,
#   '7': 0.07836990595614703,
#   '8': 0.09033368002180917,
#   '9': 0.07887243923247,
#   '10': 0.08599755776768107,
#   'text': "Life size cutouts were displayed on Capitol Hill by an advocacy group wearing Fix Fakebook ahead of Zuckerberg's https://t.co/VoCjo2lsqU"},
#  {'0': 0.20894147798444726,
#   '1': 0.0857632933104649,
#   '2': 0.0857632933104649,
#   '3': 0.1046312178387516,
#   '4': 0.20894147798444726,
#   '5': 0.0857632933104649,
#   '6': 0.0857632933104649,
#   '7': 0.0857632933104649,
#   '8': 0.08608425100354694,
#   '9': 0.0857632933104649,
#   '10': 0.0857632933104649,
#   'text': 'Most effective #DeleteFacebook message ever. https://t.co/kpr5UNZISR'},
#  {'0': 0.24048541200968357,
#   '1': 0.14002140031939295,
#   '2': 0.10226602631163004,
#   '3': 0.07106311496551797,
#   '4': 0.24048541200968357,
#   '5': 0.07818460846204267,
#   '6': 0.07102272727278619,
#   '7': 0.07111979722906692,
#   '8': 0.07102272727278619,
#   '9': 0.07404747281856928,
#   '10': 0.08076671333852428,
#   'text': 'Must be mental for Mark Zuckerberg.. one day hes at college fannying about with a new website for his pals and the https://t.co/4V1sK9dd71'},
#  {'0': 0.1926269538260139,
#   '1': 0.1500101195070829,
#   '2': 0.08533514725985214,
#   '3': 0.06993006993048953,
#   '4': 0.1926269538260139,
#   '5': 0.08531468531518761,
#   '6': 0.06993006993048953,
#   '7': 0.0853348337603245,
#   '8': 0.1006993006998997,
#   '9': 0.07367912454397232,
#   '10': 0.08713969522668781,
#   'text': '@AlexPalmerama @Madincroydon @faisalislam Funny that she believed she could delete it .. from Facebook?\n\nThe only e https://t.co/KOqW8JRka8'},
#  {'0': 0.22698076146991353,
#   '1': 0.08576329331048663,
#   '2': 0.08576329331048663,
#   '3': 0.08576329331048663,
#   '4': 0.22698076146991353,
#   '5': 0.08576329331048663,
#   '6': 0.08576329331048663,
#   '7': 0.08576329331048663,
#   '8': 0.08691289204619339,
#   '9': 0.08576329331048663,
#   '10': 0.08576329331048663,
#   'text': '@bechillcomedian Robocop, terminator, mark zuckerberg. Kiss one, marry one, kill one'},
#  {'0': 0.19394664361863834,
#   '1': 0.13564213564207855,
#   '2': 0.07538991495285521,
#   '3': 0.08993640942342752,
#   '4': 0.19394664361863834,
#   '5': 0.0880322798963856,
#   '6': 0.07215007215008667,
#   '7': 0.08444093759955283,
#   '8': 0.08802308802309844,
#   '9': 0.07215007215008667,
#   '10': 0.1002884465437902,
#   'text': '@carolecadwalla @Spookella https://t.co/xK78w91wlz \nWylie went on: I am absolutely convinced that there was a comm https://t.co/dJ9EzMdamg'},
#  {'0': 0.2001176841803185,
#   '1': 0.07836990595611552,
#   '2': 0.12167833176971354,
#   '3': 0.08382727705663981,
#   '4': 0.2001176841803185,
#   '5': 0.07836990595611552,
#   '6': 0.09508046958360906,
#   '7': 0.09621171136181833,
#   '8': 0.07836990595611552,
#   '9': 0.0789061613539312,
#   '10': 0.08906864682562288,
#   'text': 'Guardian @alexhern @carolecadwalla have revealed that This Is Your Digital Life gathered Facebook messages. Kogan https://t.co/w4U3N97N8R'},
#  {'0': 0.22417573148641814,
#   '1': 0.08417508417545755,
#   '2': 0.08417508417545755,
#   '3': 0.08419975588410872,
#   '4': 0.22417573148641814,
#   '5': 0.08417508417545755,
#   '6': 0.08422810081542596,
#   '7': 0.10227882498443318,
#   '8': 0.08417508417545755,
#   '9': 0.08417508417545755,
#   '10': 0.0842421659523262,
#   'text': 'No surprises that #GDPR and #CambridgeAnalytica feature at @PwCs #ScaleSW event! https://t.co/MwxtBKfLWu'},
#  {'0': 0.20538720538720623,
#   '1': 0.0843119479564402,
#   '2': 0.08417508417508537,
#   '3': 0.08426134459821483,
#   '4': 0.20538720538720623,
#   '5': 0.08417508417508537,
#   '6': 0.08417508417508537,
#   '7': 0.09090987342916536,
#   '8': 0.08417508417508537,
#   '9': 0.08499355557708779,
#   '10': 0.11343573635154412,
#   'text': 'What a child Zuckerberg...They told us they delete it..how stupid and naive are you..wtf?...really..ok you are no https://t.co/Cqokt6k2lX'},
#  {'0': 0.22390572390572594,
#   '1': 0.08417508417509124,
#   '2': 0.08417508417509124,
#   '3': 0.08417508417509124,
#   '4': 0.22390572390572594,
#   '5': 0.08417508417509124,
#   '6': 0.08417508417509124,
#   '7': 0.08417508417509124,
#   '8': 0.08417508417509124,
#   '9': 0.10269360269354406,
#   '10': 0.08417508417509124,
#   'text': '@Hippokloppamus It was posted on Facebook you moron delete ya tweet its totally irrelevant'},
#  {'0': 0.2053872053872148,
#   '1': 0.08417508417510508,
#   '2': 0.09441988443683741,
#   '3': 0.11036653283687084,
#   '4': 0.2053872053872148,
#   '5': 0.08417508417510508,
#   '6': 0.08417508417510508,
#   '7': 0.08477587228844644,
#   '8': 0.08417508417510508,
#   '9': 0.08417508417510508,
#   '10': 0.08417508417510508,
#   'text': 'The 2,000 Year Old Cambridge Analytica Algorithm Alive  https://t.co/3ISBw30NZe @OleryHQ @hotel_speak #insights #hospitality #Data'},
#  {'0': 0.2159645698070381,
#   '1': 0.08417508417508905,
#   '2': 0.08417508417508905,
#   '3': 0.08417508417508905,
#   '4': 0.2159645698070381,
#   '5': 0.1026936026936051,
#   '6': 0.08417508417508905,
#   '7': 0.09211623827373353,
#   '8': 0.08417508417508905,
#   '9': 0.08417508417508905,
#   '10': 0.08417508417508905,
#   'text': 'Facebook plans to let everyone unsend messages, wont let Zuckerberg until then  https://t.co/3xAT9dHjvL'},
#  {'0': 0.20538720538716804,
#   '1': 0.08417508417509469,
#   '2': 0.08417508417509469,
#   '3': 0.10269360269360117,
#   '4': 0.20538720538716804,
#   '5': 0.08417508417509469,
#   '6': 0.08417508417509469,
#   '7': 0.08417508417509469,
#   '8': 0.08417508417509469,
#   '9': 0.10269360269356795,
#   '10': 0.08417508417509469,
#   'text': "If anyone in the world is either a space lizard or secretly an android it's 100% mark zuckerberg"},
#  {'0': 0.20532961392421198,
#   '1': 0.08417508417508661,
#   '2': 0.08417508417508661,
#   '3': 0.08417508417508661,
#   '4': 0.20532961392421198,
#   '5': 0.08417508417508661,
#   '6': 0.08417508417508661,
#   '7': 0.08418794291674582,
#   '8': 0.08417508417508661,
#   '9': 0.10273833541492929,
#   '10': 0.10269360269359318,
#   'text': 'A method for predicting when our friends will die? Somebody needs to stop those creeps at #Facebook... https://t.co/YqOMMPYEwh'},
#  {'0': 0.20798041036192286,
#   '1': 0.0874125874125884,
#   '2': 0.0874125874125884,
#   '3': 0.0874125874125884,
#   '4': 0.20798041036192286,
#   '5': 0.0874125874125884,
#   '6': 0.0874125874125884,
#   '7': 0.0874125874125884,
#   '8': 0.0874125874125884,
#   '9': 0.0917382233664798,
#   '10': 0.0883932543834786,
#   'text': 'Apparently @Arron_banks hardly knew these people..... https://t.co/kAjG3EjDAc'},
#  {'0': 0.20165477347087335,
#   '1': 0.07704160246537957,
#   '2': 0.07820335343250759,
#   '3': 0.07704160246537957,
#   '4': 0.20165477347087335,
#   '5': 0.0843251116220665,
#   '6': 0.07704160246537957,
#   '7': 0.08265476020390569,
#   '8': 0.07704160246537957,
#   '9': 0.1314220367363023,
#   '10': 0.11357355467282639,
#   'text': 'Hmm.....Mark Zuckerberg wants an independent council of non-Facebookers to make the final call on removing dangerou https://t.co/PnyAOb8yhQ'},
#  {'0': 0.24143417189464272,
#   '1': 0.08417508417508762,
#   '2': 0.08417508417508762,
#   '3': 0.08417508417508762,
#   '4': 0.24143417189464272,
#   '5': 0.08417508417508762,
#   '6': 0.08417508417508762,
#   '7': 0.0850494297115432,
#   '8': 0.08417508417508762,
#   '9': 0.0842908091682008,
#   '10': 0.08417508417508762,
#   'text': '#museums #heritage adding alternative text for images on Facebook https://t.co/7BAadDVg8z'},
#  {'0': 0.18970292360024368,
#   '1': 0.17270311791320936,
#   '2': 0.06993006993053213,
#   '3': 0.07022963653643437,
#   '4': 0.18970292360024368,
#   '5': 0.08531468531523842,
#   '6': 0.06993006993053213,
#   '7': 0.07603953480576718,
#   '8': 0.10069930069996101,
#   '9': 0.0895993903949695,
#   '10': 0.0758512708731121,
#   'text': 'Dacre, Murdoch &amp; his little rat-puppet at The Sun, the ERG, Cambridge Analytica and the fetid remains of UKIP  shou https://t.co/l5EQw3ZxVU'},
#  {'0': 0.1919191919191255,
#   '1': 0.09614820022048053,
#   '2': 0.08802308802321979,
#   '3': 0.07215007215018064,
#   '4': 0.1919191919191255,
#   '5': 0.08972359243799226,
#   '6': 0.07215007215018064,
#   '7': 0.09495027973482302,
#   '8': 0.10179052799550828,
#   '9': 0.09664181178877573,
#   '10': 0.09650316357971361,
#   'text': '@Billy_Nomad_ @CommonsCMS @UKParliament @chrisinsilico @podehaye @DamianCollins @facebook A government block on https://t.co/xT6ZLax0JL'},
#  {'0': 0.2331441027037181,
#   '1': 0.0721500721508123,
#   '2': 0.11026890992685003,
#   '3': 0.0721500721508123,
#   '4': 0.2331441027037181,
#   '5': 0.10391743469869337,
#   '6': 0.0721500721508123,
#   '7': 0.0721500721508123,
#   '8': 0.08802308802383295,
#   '9': 0.0721500721508123,
#   '10': 0.10389610389284398,
#   'text': '#Facebook posted to my Linear bPad this morning with a fresco detailing our 5 years together.  It was basically a M https://t.co/A2yal0pRnr'},
#  {'0': 0.24421169061683862,
#   '1': 0.07215007215049715,
#   '2': 0.08802051643451309,
#   '3': 0.08802308802359551,
#   '4': 0.24421169061683862,
#   '5': 0.08802308802242727,
#   '6': 0.07215007215049715,
#   '7': 0.07930754234973188,
#   '8': 0.07216644720602408,
#   '9': 0.10799808941473751,
#   '10': 0.08794939363113771,
#   'text': 'If #ENG managers were #socialmedia/apps:\n \nCapello: LinkedIn (strictly business)\nMcClaren: Google+ (nobody knows ho https://t.co/lOt93Qaj0w'},
#  {'0': 0.20386826862437865,
#   '1': 0.10265293584682392,
#   '2': 0.08417508417509972,
#   '3': 0.08417508417509972,
#   '4': 0.20386826862437865,
#   '5': 0.10068610678498913,
#   '6': 0.08417508417509972,
#   '7': 0.08618258008357793,
#   '8': 0.08417508417509972,
#   '9': 0.08569402093794809,
#   '10': 0.08421575102188332,
#   'text': '@BarackObama Obama basically just said f*ck the middle-east, who cares about if they have a nuclear war. Yet when https://t.co/ZPWjIZhfco'},
#  {'0': 0.2162382841003781,
#   '1': 0.07661690710304392,
#   '2': 0.0745567316077041,
#   '3': 0.10730253353170344,
#   '4': 0.2162382841003781,
#   '5': 0.07451564828618262,
#   '6': 0.09086800758761487,
#   '7': 0.07866444035474021,
#   '8': 0.09090909090913231,
#   '9': 0.08302582298741792,
#   '10': 0.10730253353208245,
#   'text': '@Shelaco @fantasticmusic @bickypeg @RenieriArts @Cukullen @guardian @Ian56789 @2ndNewMoon @theart4peace @briangukc https://t.co/nDf0H8YkXx'},
#  {'0': 0.19506489060384594,
#   '1': 0.09242424242425343,
#   '2': 0.07708507667151454,
#   '3': 0.11196830956942275,
#   '4': 0.19506489060384594,
#   '5': 0.09242424242421114,
#   '6': 0.07575757575758724,
#   '7': 0.1138978771563499,
#   '8': 0.07580213271599132,
# ...
#   '4': 0.17482517482517698,
#   '5': 0.08741258741258849,
#   '6': 0.08741258741258849,
#   '7': 0.08741258741258849,
#   '8': 0.08741258741258849,
#   '9': 0.08741258741258849,
#   '10': 0.10664335664335528,
#   'text': "For real?...shouldn't it be illegal? https://t.co/tVgLuCAuV2"},
#  {'0': 0.17482517482517684,
#   '1': 0.08741258741258842,
#   '2': 0.08741258741258842,
#   '3': 0.08741258741258842,
#   '4': 0.17482517482517684,
#   '5': 0.08787534325035383,
#   '6': 0.08741258741258842,
#   '7': 0.08741258741258842,
#   '8': 0.08741258741258842,
#   '9': 0.12443115467930614,
#   '10': 0.08839280276963274,
#   'text': 'I think that they get things right. LOL #zuckerberg'},
#  {'0': 0.1748251748251768,
#   '1': 0.0874125874125884,
#   '2': 0.08744049906830607,
#   '3': 0.09318322630969114,
#   '4': 0.1748251748251768,
#   '5': 0.0874125874125884,
#   '6': 0.12007557532129547,
#   '7': 0.0874125874125884,
#   '8': 0.0874125874125884,
#   '9': 0.0874125874125884,
#   '10': 0.0874125874125884,
#   'text': '7 Great Applications of #MachineLearning in Pharma and Medicine https://t.co/kgqfpgF2WX   v/ @TechEmergence#AI https://t.co/kfxJquBjOs'},
#  {'0': 0.17482517482517673,
#   '1': 0.08741258741258837,
#   '2': 0.08741258741258837,
#   '3': 0.10661361588938045,
#   '4': 0.17482517482517673,
#   '5': 0.08741258741258837,
#   '6': 0.08741258741258837,
#   '7': 0.08744232816655557,
#   '8': 0.08741258741258837,
#   '9': 0.08779839297774474,
#   '10': 0.10625755107820059,
#   'text': 'Again, best analysis on Facebook! https://t.co/OFgFqQB59k'},
#  {'0': 0.17482517482517673,
#   '1': 0.0874537701502574,
#   '2': 0.08741258741258837,
#   '3': 0.08741258741258837,
#   '4': 0.17482517482517673,
#   '5': 0.08741258741258837,
#   '6': 0.10649968080745194,
#   '7': 0.08741258741258837,
#   '8': 0.10664335664335234,
#   '9': 0.08741258741258837,
#   '10': 0.0875150805108197,
#   'text': "What about 'use of buzz words' as a top AI trend? https://t.co/1clsYkpRvJ"},
#  {'0': 0.17482517482517648,
#   '1': 0.08741258741258824,
#   '2': 0.08741258741258824,
#   '3': 0.08741258741258824,
#   '4': 0.17482517482517648,
#   '5': 0.10664335664335599,
#   '6': 0.08741258741258824,
#   '7': 0.08741258741258824,
#   '8': 0.08741258741258824,
#   '9': 0.08741258741258824,
#   '10': 0.10664335664334987,
#   'text': "Watched Zuckerberg's keynote at F8. I have thoughts."},
#  {'0': 0.19405594405594323,
#   '1': 0.10664335664335106,
#   '2': 0.0874125874125882,
#   '3': 0.0874125874125882,
#   '4': 0.19405594405594323,
#   '5': 0.0874125874125882,
#   '6': 0.0874125874125882,
#   '7': 0.0874125874125882,
#   '8': 0.0874125874125882,
#   '9': 0.0874125874125882,
#   '10': 0.0874125874125882,
#   'text': 'Suspending Cambridge Analytica and SCL Group From Facebook https://t.co/I6F9XIgCpt'},
#  {'0': 0.19405594405594281,
#   '1': 0.0874125874125882,
#   '2': 0.0874125874125882,
#   '3': 0.0874125874125882,
#   '4': 0.19405594405594281,
#   '5': 0.0874125874125882,
#   '6': 0.0874125874125882,
#   '7': 0.0874125874125882,
#   '8': 0.0874125874125882,
#   '9': 0.0874125874125882,
#   '10': 0.10664335664335146,
#   'text': 'Loving this thread...  https://t.co/uoqXPytZvy'},
#  {'0': 0.17482517482517637,
#   '1': 0.09730249095257319,
#   '2': 0.08741258741258819,
#   '3': 0.08741258741258819,
#   '4': 0.17482517482517637,
#   '5': 0.08741258741258819,
#   '6': 0.08741258741258819,
#   '7': 0.10664335664335164,
#   '8': 0.08741258741258819,
#   '9': 0.09675345310336955,
#   '10': 0.08741258741258819,
#   'text': 'Easy money... https://t.co/stpWNSESk7'},
#  {'0': 0.17482517482517626,
#   '1': 0.08741258741258813,
#   '2': 0.08741258741258813,
#   '3': 0.08741258741258813,
#   '4': 0.17482517482517626,
#   '5': 0.08741258741258813,
#   '6': 0.12587412587411845,
#   '7': 0.08741258741258813,
#   '8': 0.08741258741258813,
#   '9': 0.08741258741258813,
#   '10': 0.08741258741258813,
#   'text': '#BigData Architect. - iContract ( Brighton, United Kingdom )  - [  More Info  https://t.co/6XWNPUDuGP ]  #Scala https://t.co/8Ctijzbpwz'},
#  {'0': 0.17482517482517626,
#   '1': 0.08741258741258813,
#   '2': 0.10663349362681847,
#   '3': 0.08741258741258813,
#   '4': 0.17482517482517626,
#   '5': 0.08741258741258813,
#   '6': 0.08741258741258813,
#   '7': 0.08742245042912679,
#   '8': 0.08741258741258813,
#   '9': 0.10664335664334965,
#   '10': 0.08741258741258813,
#   'text': 'Facebook on the Hill - Data Privacy Matters  https://t.co/X4iBjmaiGH'},
#  {'0': 0.17482517482517618,
#   '1': 0.08741258741258809,
#   '2': 0.12586588922143874,
#   '3': 0.08741258741258809,
#   '4': 0.17482517482517618,
#   '5': 0.08741258741258809,
#   '6': 0.08741258741258809,
#   '7': 0.08742082406526845,
#   '8': 0.08741258741258809,
#   '9': 0.08741258741258809,
#   '10': 0.08741258741258809,
#   'text': "BBC News - Facebook and You: What's The Fuss? https://t.co/BfSvBC14Gj #privacy #dataprotection #WhatHaveYouGivenAwayWithoutRealising"},
#  {'0': 0.21328671328670723,
#   '1': 0.08741258741258807,
#   '2': 0.08741258741258807,
#   '3': 0.08741258741258807,
#   '4': 0.21328671328670723,
#   '5': 0.08741258741258807,
#   '6': 0.08741258741258807,
#   '7': 0.08741258741258807,
#   '8': 0.08741258741258807,
#   '9': 0.08741258741258807,
#   '10': 0.08741258741258807,
#   'text': 'Video tips from @FalconIO   https://t.co/MC04VHLDDO'},
#  {'0': 0.17482517482517612,
#   '1': 0.08741258741258806,
#   '2': 0.105632009103052,
#   '3': 0.08741258741258806,
#   '4': 0.17482517482517612,
#   '5': 0.08741258741258806,
#   '6': 0.08741258741258806,
#   '7': 0.08741258741258806,
#   '8': 0.08741258741258806,
#   '9': 0.08741258741258806,
#   '10': 0.10765470418365548,
#   'text': '#FacebookMessenger has a new way to sell you stuff: #AugmentedReality  https://t.co/p7vfiUd5y0 #facebook https://t.co/HULPnLOa0G'},
#  {'0': 0.1748251748251761,
#   '1': 0.08741258741258805,
#   '2': 0.08741258741258805,
#   '3': 0.08741258741258805,
#   '4': 0.1748251748251761,
#   '5': 0.08856142365790237,
#   '6': 0.08741258741258805,
#   '7': 0.08741258741258805,
#   '8': 0.08741258741258805,
#   '9': 0.10664335664335188,
#   '10': 0.10549452039804147,
#   'text': 'Zuckerberg, Mueller. Why al the german namens? Fourth Reich By Jim Marrs. Yes with 2 rr s   Great Guy'},
#  {'0': 0.174825174825176,
#   '1': 0.087412587412588,
#   '2': 0.087412587412588,
#   '3': 0.087412587412588,
#   '4': 0.174825174825176,
#   '5': 0.087412587412588,
#   '6': 0.087412587412588,
#   '7': 0.087412587412588,
#   '8': 0.087412587412588,
#   '9': 0.087412587412588,
#   '10': 0.1258741258741199,
#   'text': 'A very interesting thread. #Facebook https://t.co/UDehMvJRGc'},
#  {'0': 0.174825174825176,
#   '1': 0.087412587412588,
#   '2': 0.10664335664335377,
#   '3': 0.087412587412588,
#   '4': 0.174825174825176,
#   '5': 0.087412587412588,
#   '6': 0.087412587412588,
#   '7': 0.087412587412588,
#   '8': 0.10664335664335425,
#   '9': 0.087412587412588,
#   '10': 0.087412587412588,
#   'text': 'Mark Zuckerbergs data was collected by third parties https://t.co/92BIPhwtdG https://t.co/qNNkI52geE'},
#  {'0': 0.19405594405594234,
#   '1': 0.08741258741258799,
#   '2': 0.08741258741258799,
#   '3': 0.08832671781009571,
#   '4': 0.19405594405594234,
#   '5': 0.08741258741258799,
#   '6': 0.08741258741258799,
#   '7': 0.08741258741258799,
#   '8': 0.08741258741258799,
#   '9': 0.10572922624584598,
#   '10': 0.08741258741258799,
#   'text': 'KOOL-MOSING-ALONGKOOL-MO-&amp;-Huey Lewis &amp; The NewsSingsThe Power Of Love4The Duke and Duchess of Camb https://t.co/vo5uITyzol'},
#  {'0': 0.1940559440559413,
#   '1': 0.08741258741258798,
#   '2': 0.08741258741258798,
#   '3': 0.10664335664335482,
#   '4': 0.1940559440559413,
#   '5': 0.08741258741258798,
#   '6': 0.08741258741258798,
#   '7': 0.08741258741258798,
#   '8': 0.08741258741258798,
#   '9': 0.08741258741258798,
#   '10': 0.08741258741258798,
#   'text': 'Another #dating #service - do we really need #Facebook to do this to us ?\n\n#JMKWednesday #JMK_Wednesday https://t.co/bJRuGBhzRo'},
#  {'0': 0.19421312252196554,
#   '1': 0.08741258741258796,
#   '2': 0.08741258741258796,
#   '3': 0.08742344780196896,
#   '4': 0.19421312252196554,
#   '5': 0.08741258741258796,
#   '6': 0.08741258741258796,
#   '7': 0.08741258741258796,
#   '8': 0.0910682392992152,
#   '9': 0.08741258741258796,
#   '10': 0.10281966590132254,
#   'text': 'Great to see updates like this happening, about time too!  #facebook #digitalmarketing\nhttps://t.co/4GRwAdiOkV'},
#  {'0': 0.17482517482517582,
#   '1': 0.08741258741258791,
#   '2': 0.08741258741258791,
#   '3': 0.1066433566433518,
#   '4': 0.17482517482517582,
#   '5': 0.08741258741258791,
#   '6': 0.1066433566433569,
#   '7': 0.08741258741258791,
#   '8': 0.08741258741258791,
#   '9': 0.08741258741258791,
#   '10': 0.08741258741258791,
#   'text': 'Take the #SQL headache out of your #BigData project. Use  Kognitio #hadoop #bigdata #mapr #inmemory #MPP https://t.co/vzDJdjUhxf'},
#  {'0': 0.19405594405594376,
#   '1': 0.08741258741258788,
#   '2': 0.08742355577513998,
#   '3': 0.08941143459132497,
#   '4': 0.19405594405594376,
#   '5': 0.09135340845394402,
#   '6': 0.08741258741258788,
#   '7': 0.08741258741258788,
#   '8': 0.08741258741258788,
#   '9': 0.08741258741258788,
#   '10': 0.10069272006070785,
#   'text': 'THANK YOU PART 1 OF 2\n300 FOLLOWS FACEBOOK\n300 SUBS YOUTUBE\n\n#Youtube #Facebook #Subs https://t.co/TImcIPvG67'},
#  {'0': 0.1748251748251757,
#   '1': 0.08741258741258785,
#   '2': 0.10663349084631611,
#   '3': 0.08741258741258785,
#   '4': 0.1748251748251757,
#   '5': 0.1066433566433526,
#   '6': 0.08741258741258785,
#   '7': 0.0874224532096285,
#   '8': 0.08741258741258785,
#   '9': 0.08741258741258785,
#   '10': 0.08741258741258785,
#   'text': "It's the big #zuckerberg speaks in front of #Congress #Facebook #bingo! #MarkZuckerberg #CambridgeAnalytics https://t.co/zreoivY1xI"},
#  {'0': 0.1748251748251756,
#   '1': 0.0874125874125878,
#   '2': 0.10664335664335352,
#   '3': 0.0874125874125878,
#   '4': 0.1748251748251756,
#   '5': 0.10664335664335615,
#   '6': 0.0874125874125878,
#   '7': 0.0874125874125878,
#   '8': 0.0874125874125878,
#   '9': 0.0874125874125878,
#   '10': 0.0874125874125878,
#   'text': 'Hard Questions: What Data Does Facebook Collect When Im Not Using Facebook, and Why? | https://t.co/leCzRQ4Jbl'},
#  {'0': 0.18747491214981832,
#   '1': 0.0874125874125878,
#   '2': 0.0939936193187132,
#   '3': 0.0874125874125878,
#   '4': 0.18747491214981832,
#   '5': 0.0874125874125878,
#   '6': 0.0874125874125878,
#   '7': 0.0874125874125878,
#   '8': 0.0874125874125878,
#   '9': 0.0874125874125878,
#   '10': 0.10664335664335403,
#   'text': 'Thats a lot of Zuckerberg shares. https://t.co/K1J7GNbXJQ'},
#  {'0': 0.17482517482517557,
#   '1': 0.08741258741258778,
#   '2': 0.08741258741258778,
#   '3': 0.08741258741258778,
#   '4': 0.17482517482517557,
#   '5': 0.08741258741258778,
#   '6': 0.12587412587412217,
#   '7': 0.08741258741258778,
#   '8': 0.08741258741258778,
#   '9': 0.08741258741258778,
#   '10': 0.08741258741258778,
#   'text': "Richmond's Information Science Daily! https://t.co/DMKFCnHDPM #machinelearning #bigdata"},
#  {'0': 0.17482517482517557,
#   '1': 0.08741258741258778,
#   '2': 0.08741258741258778,
#   '3': 0.08741258741258778,
#   '4': 0.17482517482517557,
#   '5': 0.1258741258741221,
#   '6': 0.08741258741258778,
#   '7': 0.08741258741258778,
#   '8': 0.08741258741258778,
#   '9': 0.08741258741258778,
#   '10': 0.08741258741258778,
#   'text': 'Hear, hear  https://t.co/7cVqSAqNRK'},
#  {'0': 0.20603207394002393,
#   '1': 0.08741258741258776,
#   '2': 0.08741258741258776,
#   '3': 0.08741258741258776,
#   '4': 0.20603207394002393,
#   '5': 0.08741258741258776,
#   '6': 0.08741258741258776,
#   '7': 0.094667226759274,
#   '8': 0.08741258741258776,
#   '9': 0.08741258741258776,
#   '10': 0.08741258741258776,
#   'text': 'Facebook annonce le dating sur son app ! Quand Facebook copie Tinder ! #F8 #Facebook'},
#  {'0': 0.1748251748251755,
#   '1': 0.08741258741258776,
#   '2': 0.08741258741258776,
#   '3': 0.08741258741258776,
#   '4': 0.1748251748251755,
#   '5': 0.08741258741258776,
#   '6': 0.10664335664335452,
#   '7': 0.08741258741258776,
#   '8': 0.08741258741258776,
#   '9': 0.10547959241253568,
#   '10': 0.08857635164340781,
#   'text': 'So many things to learn!!! https://t.co/0qeHv6A0B1'},
#  {'0': 0.17482517482517546,
#   '1': 0.08741258741258773,
#   '2': 0.08741258741258773,
#   '3': 0.08741860938883686,
#   '4': 0.17482517482517546,
#   '5': 0.10804476827941302,
#   '6': 0.08741258741258773,
#   '7': 0.0874187417719773,
#   '8': 0.08741258741258773,
#   '9': 0.08741258741258773,
#   '10': 0.10522976867165867,
#   'text': '@BBCJonSopel Substitute Zuckerberg for Pep Guardiola - the answers would be great.'},
#  {'0': 0.17482517482517543,
#   '1': 0.08741258741258771,
#   '2': 0.125874125874123,
#   '3': 0.08741258741258771,
#   '4': 0.17482517482517543,
#   '5': 0.08741258741258771,
#   '6': 0.08741258741258771,
#   '7': 0.08741258741258771,
#   '8': 0.08741258741258771,
#   '9': 0.08741258741258771,
#   '10': 0.08741258741258771,
#   'text': 'Facebook moving most users from protection of EU privacy law  Silicon Valley https://t.co/jWSUHDZTZW'},
#  {'0': 0.17482517482517537,
#   '1': 0.08741258741258769,
#   '2': 0.08741258741258769,
#   '3': 0.08741258741258769,
#   '4': 0.17482517482517537,
#   '5': 0.09865735712519011,
#   '6': 0.08741258741258769,
#   '7': 0.11462266922791921,
#   '8': 0.08741927434618921,
#   '9': 0.08741258741258769,
#   '10': 0.08741258741258769,
#   'text': '#Facebook #Zuckerberg  is in #Paris - already faced EU committee over Data scandal. https://t.co/3IBYLS2Vap'},
#  {'0': 0.1940559440559424,
#   '1': 0.08741258741258769,
#   '2': 0.08741258741258769,
#   '3': 0.08741258741258769,
#   '4': 0.1940559440559424,
#   '5': 0.10664335664335602,
#   '6': 0.08741258741258769,
#   '7': 0.08741258741258769,
#   '8': 0.08741258741258769,
#   '9': 0.08741258741258769,
#   '10': 0.08741258741258769,
#   'text': 'Wat een heerlijke video: These are the most confusing questions Congress asked Zuckerberg https://t.co/z4TFbossuX'},
#  {'0': 0.17482517482517526,
#   '1': 0.1258741258741237,
#   '2': 0.08741258741258763,
#   '3': 0.08741258741258763,
#   '4': 0.17482517482517526,
#   '5': 0.08741258741258763,
#   '6': 0.08741258741258763,
#   '7': 0.08741258741258763,
#   '8': 0.08741258741258763,
#   '9': 0.08741258741258763,
#   '10': 0.08741258741258763,
#   'text': 'Robert Mercer, Steve Bannon, Donald Trump, Nigel Farage, Jacob Rees Mogg, Michael Gove, Cambridge Analytica, Vote L https://t.co/5gJwzJBcrm'},
#  {'0': 0.17482517482517518,
#   '1': 0.08741258741258759,
#   '2': 0.125825715512047,
#   '3': 0.08741258741258759,
#   '4': 0.17482517482517518,
#   '5': 0.08741258741258759,
#   '6': 0.08741258741258759,
#   '7': 0.0874208282279348,
#   '8': 0.08741258741258759,
#   '9': 0.08741258741258759,
#   '10': 0.08745275695931747,
#   'text': 'Privacy Information https://t.co/An1a3aDxVS'},
#  {'0': 0.17482517482517518,
#   '1': 0.08741258741258759,
#   '2': 0.08741258741258759,
#   '3': 0.08741258741258759,
#   '4': 0.17482517482517518,
#   '5': 0.08741258741258759,
#   '6': 0.12587412587412408,
#   '7': 0.08741258741258759,
#   '8': 0.08741258741258759,
#   '9': 0.08741258741258759,
#   '10': 0.08741258741258759,
#   'text': 'The latest Analytics Network Daily Roundup! https://t.co/IQqVScFn2w Thanks to @FlyingBinary #meltdown #microsoft'},
#  {'0': 0.17482517482517504,
#   '1': 0.08741258741258752,
#   '2': 0.08741258741258752,
#   '3': 0.08741258741258752,
#   '4': 0.17482517482517504,
#   '5': 0.08741258741258752,
#   '6': 0.12587412587412483,
#   '7': 0.08741258741258752,
#   '8': 0.08741258741258752,
#   '9': 0.08741258741258752,
#   '10': 0.08741258741258752,
#   'text': 'The latest  Karl Ffrench - Daily ! https://t.co/h50k9ZQiRN Thanks to @raimeygallant #bigdata #datascience'},
#  {'0': 0.17715523066531474,
#   '1': 0.0797448165869485,
#   '2': 0.0797448165869485,
#   '3': 0.09781310973769625,
#   '4': 0.17715523066531474,
#   '5': 0.08850385588905971,
#   '6': 0.11429485098826157,
#   '7': 0.08727044543089008,
#   '8': 0.09727167895841346,
#   '9': 0.0809125189206956,
#   '10': 0.09728867623577157,
#   'text': 'Digital marketing is an investment. It takes time to mature before it can pay you back. #facebook https://t.co/BJvLD5JZsJ'},
#  {'0': 0.1721959096656846,
#   '1': 0.0833756887573752,
#   '2': 0.1082782874460103,
#   '3': 0.09628837064219813,
#   '4': 0.1721959096656846,
#   '5': 0.07575757575758044,
#   '6': 0.07575757575758044,
#   '7': 0.09094358224742409,
#   '8': 0.0924242424242429,
#   '9': 0.10242652900730662,
#   '10': 0.10255223829459728,
#   'text': 'the entire purpose of #Facebook is to make #money by treating its #users as the #product that it sells to https://t.co/lpg5diRH2d'},
#  ...]

# %%
import topicvisexplorer
import importlib
importlib.reload(topicvisexplorer)
# Out:
# c:\users\gonza\tesisenv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <module 'topicvisexplorer' from 'C:\\Users\\gonza\\Desktop\\TopicVisExplorer\\topicvisexplorer.py'>

# %%
vis = topicvisexplorer.TopicVisExplorer("borrar_nombre")

vis.load_single_corpus_data("single_corpus_europe_cambridge_analytica_lda_mallet_with_word_embedding.pkl")
# Out:
# c:\users\gonza\tesisenv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Data loaded sucessfully

# %%
vis.run()
# Out:
#  * Serving Flask app "borrar_nombre" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# c:\users\gonza\tesisenv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [18/Jan/2021 15:33:04] "GET /singlecorpus HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2021 15:33:04] "GET /static/js/jquery.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2021 15:33:04] "GET /static/js/popper.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2021 15:33:04] "GET /static/fontawesome/css/fontawesome.css HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2021 15:33:04] "GET /static/fontawesome/css/solid.css HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2021 15:33:04] "GET /static/fontawesome/css/brands.css HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2021 15:33:04] "GET /static/css/bootstrap-table.min.css HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2021 15:33:04] "GET /static/css/bootstrap.min.css HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2021 15:33:04] "GET /static/css/LDAvis.css HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2021 15:33:04] "GET /static/css/nouislider.css HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2021 15:33:04] "GET /static/js/bootstrap.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2021 15:33:04] "GET /static/js/d3.v5.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2021 15:33:04] "GET /static/js/sankey.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2021 15:33:04] "GET /static/js/xlsx.full.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2021 15:33:05] "GET /static/js/FileSaver.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2021 15:33:05] "GET /static/js/nouislider.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2021 15:33:05] "GET /static/js/bootstrap-table.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2021 15:33:05] "GET /static/js/popper.min.js.map HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Jan/2021 15:33:05] "GET /static/js/bootstrap.min.js.map HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Jan/2021 15:33:05] "GET /static/css/bootstrap.min.css.map HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Jan/2021 15:33:06] "GET /static/fontawesome/webfonts/fa-solid-900.woff2 HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2021 15:33:07] "GET /static/js/LDAvis.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2021 15:33:07] "GET /SingleCorpus_documents HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Jan/2021 15:33:07] "GET /favicon.ico HTTP/1.1" 404 -
# calculando new matrix after merged topic
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# ...
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:100: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if item['term'] in wordembedding:
# C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py:101: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   topkeywords_vector += wordembedding[item['term']]/ranking
# [2021-01-18 15:33:14,482] ERROR in app: Exception on /get_new_topic_vector [POST]
# Traceback (most recent call last):
#   File "c:\users\gonza\tesisenv\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\users\gonza\tesisenv\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\users\gonza\tesisenv\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\users\gonza\tesisenv\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\users\gonza\tesisenv\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\users\gonza\tesisenv\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\users\gonza\tesisenv\lib\site-packages\flask_classful.py", line 268, in proxy
#     response = view(**request.view_args)
#   File "c:\users\gonza\tesisenv\lib\site-packages\flask_classful.py", line 239, in inner
#     return fn(*args, **kwargs)
#   File "C:\Users\gonza\Desktop\TopicVisExplorer\topicvisexplorer.py", line 329, in get_new_topic_vector
#     topkeywords_vectors_dict_1, relevantdocuments_vectors_dict_1 = get_topkeywords_relevantdocuments_vectors(word_embedding_model, lda_model,pd.DataFrame(single_corpus_data['relevantDocumentsDict']),  topn_terms, tinfo_collection_1, topk_documents)
#   File "C:\Users\gonza\Desktop\TopicVisExplorer\_topic_similarity_matrix.py", line 113, in get_topkeywords_relevantdocuments_vectors
#     for index, item in matrix_documents_topic_contribution.sort_values(by=[topic_id], ascending=False)[[topic_id,matrix_documents_topic_contribution.columns[-1]]][0:topkdocuments].iterrows():
#   File "c:\users\gonza\tesisenv\lib\site-packages\pandas\core\frame.py", line 5298, in sort_values
#     k = self._get_label_or_level_values(by, axis=axis)
#   File "c:\users\gonza\tesisenv\lib\site-packages\pandas\core\generic.py", line 1563, in _get_label_or_level_values
#     raise KeyError(key)
# KeyError: 0
# 127.0.0.1 - - [18/Jan/2021 15:33:14] "POST /get_new_topic_vector HTTP/1.1" 500 -

# %%
topicvisexplorer.single_corpus_data.keys()
# Out:
# c:\users\gonza\tesisenv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# dict_keys(['data_dict', 'PreparedDataObtained', 'relevantDocumentsDict', 'word_embedding_model', 'tinfo_collection', 'topkeywords_vectors_dict', 'relevantdocuments_vectors_dict', 'lda_model', 'corpus', 'id2word', 'topic_similarity_matrix', 'topic.order', 'new_circle_positions'])

# %%
import unidecode
import _prepare
import gensim_helpers
import spacy
import re, numpy as np, pandas as pd

from string import punctuation
from string import digits
from nltk.tokenize import TweetTokenizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
from gensim.utils import lemmatize, simple_preprocess

'''My own tokenizer '''
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]


#this should be easy to change for users
punctuation+="¡¿<>'`"
punctuation+='"'
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])    
stop_words = stopwords.words('english')

#Remove digits and puntuaction
remove_digits = str.maketrans(digits, ' '*len(digits))#remove_digits = str.maketrans('', '', digits)
remove_punctuation = str.maketrans(punctuation, ' '*len(punctuation))#remove_punctuation = str.maketrans('', '', punctuation)
remove_hashtags_caracter = str.maketrans('#', ' '*len('#'))
#las palabras de los hashtag se mantiene, pero no el simbolo. 

tknzr = TweetTokenizer()
def sent_to_words(sentence):
    return tknzr.tokenize(sentence)
    
def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    doc = nlp(" ".join(texts)) 
    texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out
        
def text_cleaner(tweet):
    tweet = tweet.translate(remove_digits)
    #tweet = tweet.lower() it wasn't a good idea,, we lost a lot of
    tweet = tweet.translate(remove_punctuation)
    tweet = tweet.translate(remove_hashtags_caracter)
    tweet = tweet.lower()
    tweet = unidecode.unidecode(tweet)
    tweet = sent_to_words(tweet)
    tweet = remove_stopwords(tweet)
    new_tweet  = []
    for elem in tweet:
        if len(elem)>0:
            new_tweet.append(elem[0])
    tweet = lemmatization(new_tweet, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])
    return tweet[0]

#Note, that vectors are going to be calculated according to topic order of PreparedData
def get_dicts_relevant_keywords_documents(lda_model,df_relevant_documents, n_terms, PreparedData_dict_with_more_info):
    num_topics = lda_model.num_topics
    topKeywordsDict = {}
    for topic_id in range(num_topics):        
        topKeywordsDict[topic_id] = []        
        def save_relevant_keywords_in_dict(row):
            topKeywordsDict[topic_id].append({  #el topic_id, debe ser segun el orden de lda_model
                "term":row['Term'],
                "relevance":row['relevance']
            })
        PreparedData_dict_with_more_info.loc[PreparedData_dict_with_more_info['Category'] == 'Topic'+str(topic_id+1)].sort_values(by='relevance', ascending=False)[['Term','relevance']][:n_terms].apply(save_relevant_keywords_in_dict, axis=1)    
    return topKeywordsDict


def getDocumentVector(text, wordembedding,  topic_id ,  PreparedData_dict_with_more_info):    
    #print("este es el texto", text)
    list_terms_relevance = PreparedData_dict_with_more_info.loc[PreparedData_dict_with_more_info['Category'] == 'Topic'+str(topic_id+1)].sort_values(by='relevance', ascending=False)['Term'].tolist()
    document_vector = 0.0
    words_found = set()
    for word in text_cleaner(text):    
        if word in list_terms_relevance:
            raking_word = float(list_terms_relevance.index(word)+1)
            if word in wordembedding: #if word in wordembedding.wv:
                #print("WORD FOUND", word, raking_word)
                document_vector+=wordembedding[word]/raking_word #aqui hay que ponderar
                words_found.add(word.upper())
            else:
                pass
                #print("WARNING, Word not found:", word)    
    return document_vector
            
def get_topkeywords_relevantdocuments_vectors(wordembedding, lda_model,matrix_documents_topic_contribution,  n_terms,PreparedData_dict_with_more_info, topkdocuments): #n_terms : numero de top keywords a considerar
    topKeywordsDict = get_dicts_relevant_keywords_documents(lda_model, matrix_documents_topic_contribution, n_terms,   PreparedData_dict_with_more_info)

    ##Create top keyword vector per topic
    topkeywords_vectors_dict = {}
    num_topics = lda_model.num_topics
    for topic_id in range(num_topics):
        topkeywords_vector = 0
        ranking = 1.0
        for item in topKeywordsDict[topic_id]:
            if item['term'] in wordembedding: 
                topkeywords_vector += wordembedding[item['term']]/ranking
            else:
                pass
                #print("WARNING NOT FOUND: ", item['term']," position:",ranking)
            ranking+=1
        topkeywords_vectors_dict[topic_id] = topkeywords_vector
        
    #Create a top relevant document vector    
    relevantdocuments_vectors_dict = {}
    for topic_id in range(num_topics):
        relevantDocumentsvector = 0.0
        j = 0
        for index, item in matrix_documents_topic_contribution.sort_values(by=[topic_id], ascending=False)[[topic_id,matrix_documents_topic_contribution.columns[-1]]][0:topkdocuments].iterrows():
            j+=1                                            
            relevantDocumentsvector+= float(item[topic_id])*getDocumentVector(item[matrix_documents_topic_contribution.columns[-1]], wordembedding, topic_id, PreparedData_dict_with_more_info) 
            #print("document contribution", item[topic_id])
        relevantdocuments_vectors_dict[topic_id] = relevantDocumentsvector        
    
    return (topkeywords_vectors_dict, relevantdocuments_vectors_dict)

#Here, we calculate once the topkeywords_vector and the relevant documents_vector for each topic
#We are going to calculate several times:      #final topic vector = (lambda)topic_keyword_vector + (lambda-1)topic_document_vector
#because we are going to try different lambda (between 0 and 1)


#This matrix is calculated by a specific lambda. 
def get_matrix_by_lambda(wordembedding, lda_model_1,most_relevant_documents_1,lda_model_2,most_relevant_documents_2, n_terms, lambda_, PreparedData_dict_with_more_info_1, PreparedData_dict_with_more_info_2, topkdocuments, relevance_lambda, topkeywords_vectors_dict_1, relevantdocuments_vectors_dict_1, topkeywords_vectors_dict_2, relevantdocuments_vectors_dict_2):
    #final topic vector = (lambda)topic_keyword_vector + (lambda-1)topic_document_vector
    

    #get final topic vectors model 1    
    num_topics_1 = lda_model_1.num_topics
    final_topic_vectors_dict_1 = dict()
    for topic_id in range(num_topics_1):
        final_topic_vector = lambda_*topkeywords_vectors_dict_1[topic_id]+(1-lambda_)*relevantdocuments_vectors_dict_1[topic_id]
        final_topic_vectors_dict_1[topic_id] = final_topic_vector
    
    #get final topic vectors model 2
    num_topics_2 = lda_model_2.num_topics
    final_topic_vectors_dict_2 = dict()
    for topic_id in range(num_topics_2):
        final_topic_vector = lambda_*topkeywords_vectors_dict_2[topic_id]+(1-lambda_)*relevantdocuments_vectors_dict_2[topic_id]
        final_topic_vectors_dict_2[topic_id] = final_topic_vector
    


    #lets calculate the topic similarity matrix for this omega (lambda_)
    topic_similarity_matrix = []
    for i in range(num_topics_1):
        row = []
        for j in range(num_topics_2):
            topic_i = final_topic_vectors_dict_1[i].reshape(1,-1)
            topic_j = final_topic_vectors_dict_2[j].reshape(1,-1)
            row.append(float(cosine_similarity(topic_i,topic_j)))
        topic_similarity_matrix.append(row)
    topic_similarity_matrix= np.asarray(topic_similarity_matrix)
    return topic_similarity_matrix

def get_dict_topic_similarity_matrix(wordembedding, lda_model_1,relevantDocumentsDict_1,lda_model_2,relevantDocumentsDict_2, topn_terms, PreparedData_dict_with_more_info_1, PreparedData_dict_with_more_info_2, topkdocuments, relevance_lambda, tinfo_collection_1, tinfo_collection_2, topkeywords_vectors_dict_1,topkeywords_vectors_dict_2,  relevantdocuments_vectors_dict_1, relevantdocuments_vectors_dict_2):    
    
    
    #calculate topic similarity metric for different omega values
    
    i = 0.0
    matrices_dict = dict()
    while i <=1.01:
        lambda_ = round(i*100/100,2)        
        print("Calculating for omega = ", lambda_)
        matrix = get_matrix_by_lambda(wordembedding, lda_model_1, relevantDocumentsDict_1, lda_model_2, relevantDocumentsDict_2,topn_terms, lambda_,  tinfo_collection_1, tinfo_collection_2, topkdocuments, relevance_lambda, topkeywords_vectors_dict_1, relevantdocuments_vectors_dict_1 , topkeywords_vectors_dict_2, relevantdocuments_vectors_dict_2 )    
        matrices_dict[lambda_] = matrix
        i+=0.01
    return matrices_dict
# Out:
# c:\users\gonza\tesisenv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#compare relevant documents
data.keys()
# Out:
# c:\users\gonza\tesisenv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# dict_keys(['relevantDocumentsDict_new', 'lamData_new'])

# %%
data['relevantDocumentsDict_new']
# Out:
# c:\users\gonza\tesisenv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [{'0': 0.32864403719336244,
#   '1': 0.0808886074559624,
#   '2': 0.07215007215008161,
#   '3': 0.07218954416068951,
#   '4': 0.32864403719336244,
#   '5': 0.07914251730082758,
#   '6': 0.07215007215008161,
#   '7': 0.07823649103197788,
#   '8': 0.07229851425685374,
#   '9': 0.07215007215008161,
#   '10': 0.07215007215008161,
#   'text': '.\n#NYCACC\n#DogsOfTwitter\nMAYBACK #VID\n#ATTENTION\nEVERY1 WHOS INTERESTED IN\n#FOSTERING (for no costs to u) OR https://t.co/fogEzEdp4m'},
#  {'0': 0.3100961591057768,
#   '1': 0.08661796324570185,
#   '2': 0.0721500721502208,
#   '3': 0.0721500721502208,
#   '4': 0.3100961591057768,
#   '5': 0.07680160895748742,
#   '6': 0.07230599429859572,
#   '7': 0.0721500721502208,
#   '8': 0.0721500721502208,
#   '9': 0.0930664918932258,
#   '10': 0.07251149389832916,
#   'text': 'So, #Facebook. How are you? When are you going to reply to my numerous submitted help requests? Didnt you know it https://t.co/UJ92gKSVFd'},
#  {'0': 0.28967642526959203,
#   '1': 0.07704160246533778,
#   '2': 0.07704160246533778,
#   '3': 0.07704160246533778,
#   '4': 0.28967642526959203,
#   '5': 0.07704160246533778,
#   '6': 0.07704160246533778,
#   '7': 0.09399075500770566,
#   '8': 0.07704160246533778,
#   '9': 0.07704160246533778,
#   '10': 0.07704160246533778,
#   'text': "The horror when you realise you've only deactivated your Facebook account instead of deleting it and the mad panic https://t.co/m6RoP0BlA8"},
#  {'0': 0.2681401095771664,
#   '1': 0.07575757575758127,
#   '2': 0.09242424242424464,
#   '3': 0.07575757575758127,
#   '4': 0.2681401095771664,
#   '5': 0.07575757575758127,
#   '6': 0.07575757575758127,
#   '7': 0.10909090909089474,
#   '8': 0.07575757575758127,
#   '9': 0.07579043205297259,
#   '10': 0.0757664280668152,
#   'text': "If you send a message to Mark Zuckerberg or to any other Facebook executive, they'll keep a copy of it forever. But https://t.co/YvCSmYgJdi"},
#  {'0': 0.2638117745064796,
#   '1': 0.07451564828614209,
#   '2': 0.10719805523442971,
#   '3': 0.07451564828614209,
#   '4': 0.2638117745064796,
#   '5': 0.07451564828614209,
#   '6': 0.09097732570691448,
#   '7': 0.08124159347254675,
#   '8': 0.07451564828614209,
#   '9': 0.07532629848307035,
#   '10': 0.0833823594519908,
#   'text': 'As part of the GDPR / data protection regulations we want to make sure we only send marketing messages to those who https://t.co/5Erh0rkSAW'},
#  {'0': 0.2796969553355361,
#   '1': 0.07575757575759981,
#   '2': 0.07881766651039054,
#   '3': 0.07575757575759981,
#   '4': 0.2796969553355361,
#   '5': 0.07575757575759981,
#   '6': 0.07575757575759981,
#   '7': 0.09450441936243192,
#   '8': 0.07575757575759981,
#   '9': 0.09243550424604244,
#   '10': 0.07575757575759981,
#   'text': 'Steve Zebs privacy policy. \nBy excepting a friend request you agree to receive messages from Steve Zebs via Faceboo https://t.co/N6vrTwI8Au'},
#  {'0': 0.24415478791362916,
#   '1': 0.07451564828615065,
#   '2': 0.07451564828615065,
#   '3': 0.09090909090909582,
#   '4': 0.24415478791362916,
#   '5': 0.09090909090907977,
#   '6': 0.07451564828615065,
#   '7': 0.07451564828615065,
#   '8': 0.09090909090909163,
#   '9': 0.11053481823525163,
#   '10': 0.07452052797924921,
#   'text': '@FenauxRaphael @facebook Dont know this guy, accounts been hacked, but @facebook wont let me delete this account, https://t.co/o6Zgjh8HKw'},
#  {'0': 0.2515153779998892,
#   '1': 0.0826446280991829,
#   '2': 0.0826446280991829,
#   '3': 0.0826446280991829,
#   '4': 0.2515153779998892,
#   '5': 0.0826446280991829,
#   '6': 0.0826446280991829,
#   '7': 0.0826446280991829,
#   '8': 0.0826446280991829,
#   '9': 0.08667985321614087,
#   '10': 0.08329237208968972,
#   'text': 'Who cares! Look - Tom from MySpace is wearing different clothes!\n\nWHAT THE FUCK IS GOING ON PEOPLE? https://t.co/vPEq09LWhZ'},
#  {'0': 0.2641297437875425,
#   '1': 0.08057502717971433,
#   '2': 0.08802308802343525,
#   '3': 0.08485969001327809,
#   '4': 0.2641297437875425,
#   '5': 0.08483895592274543,
#   '6': 0.08802308802343568,
#   '7': 0.09022242394275166,
#   '8': 0.07246099600180773,
#   '9': 0.07471691495492971,
#   '10': 0.07215007215035953,
#   'text': "Will #Facebook's future look like the #Regulatory difficulties encountered by #Microsft in the past? \n\nIs GoogleBoo https://t.co/2sPBJXmNdm"},
#  {'0': 0.24110960232393835,
#   '1': 0.09087647642656249,
#   '2': 0.0745156482862055,
#   '3': 0.0745156482862055,
#   '4': 0.24110960232393835,
#   '5': 0.10730253353207854,
#   '6': 0.0745156482862055,
#   '7': 0.0745156482862055,
#   '8': 0.0745156482862055,
#   '9': 0.10787484828199144,
#   '10': 0.08025829800440164,
#   'text': 'I deleted my #Facebook account last week. It was painful to let go of something that was in my life for 10 years, i https://t.co/OZ2GUgdHSF'},
#  {'0': 0.2521346874476126,
#   '1': 0.08407452693437903,
#   '2': 0.08698031924523729,
#   '3': 0.07102272727321478,
#   '4': 0.2521346874476126,
#   '5': 0.07102272727321478,
#   '6': 0.07102272727321478,
#   '7': 0.08888833564025987,
#   '8': 0.13280849436643727,
#   '9': 0.07102272727321478,
#   '10': 0.07102272727321478,
#   'text': 'Just browsing through Facebook for a bit before bed: disabled man denied public transit, dog dead at groomer, dogs https://t.co/2jtQYk4hIC'},
#  {'0': 0.2596323869813355,
#   '1': 0.07837799029429342,
#   '2': 0.07836990595611693,
#   '3': 0.07836990595611693,
#   '4': 0.2596323869813355,
#   '5': 0.07839847530419389,
#   '6': 0.07836990595611693,
#   '7': 0.07836990595611693,
#   '8': 0.09585620059496158,
#   '9': 0.07836990595611693,
#   '10': 0.09588541704463097,
#   'text': "I am a young disabled person and I have decided to #DeleteFacebook- find out the reasons behind @emmavogelmann's https://t.co/VPSrN03yje"},
#  {'0': 0.3081380747244086,
#   '1': 0.08276797829044423,
#   '2': 0.06784260515611228,
#   '3': 0.06784260515611228,
#   '4': 0.3081380747244086,
#   '5': 0.08285912137887953,
#   '6': 0.06814374640840888,
#   '7': 0.08276797829040462,
#   '8': 0.0741019340146289,
#   '9': 0.06856323657098384,
#   '10': 0.09697272000961674,
#   'text': 'Log onto FB and first two posts on my timeline are about a court case were a man was caught drunk riding a horse an https://t.co/Q9EWBhkdLT'},
#  {'0': 0.24338986847234742,
#   '1': 0.08505033672964367,
#   '2': 0.08116883116890028,
#   '3': 0.08116883116890028,
#   '4': 0.24338986847234742,
#   '5': 0.08117576917819097,
#   '6': 0.08116883116890028,
#   '7': 0.08116883116890028,
#   '8': 0.08138313142120451,
#   '9': 0.10253218092315433,
#   '10': 0.08179338859985791,
#   'text': "What about people's accounts you disable for spurious reasons?\n@facebook #DeleteFacebook #facebookdisabled  https://t.co/PrSaCDCd5s"},
#  {'0': 0.22863097677808286,
#   '1': 0.13779357475516513,
#   '2': 0.06892114509926826,
#   '3': 0.06892148077245004,
#   '4': 0.22863097677808286,
#   '5': 0.06888968437750131,
#   '6': 0.0688705234162816,
#   '7': 0.0688705234162816,
#   '8': 0.08402203856770543,
#   '9': 0.07974522796396775,
#   '10': 0.125334824853296,
#   'text': '@DawkinsDog @facebook Michelle with a degree. Melania that cannot string a sentence together and plagiarized Michel https://t.co/neMO5VkvSz'},
#  {'0': 0.24241749763389575,
#   '1': 0.08417508417508607,
#   '2': 0.08417508417508607,
#   '3': 0.08417508417508607,
#   '4': 0.24241749763389575,
#   '5': 0.08417508417508607,
#   '6': 0.08417508417508607,
#   '7': 0.08417508417508607,
#   '8': 0.08417508417508607,
#   '9': 0.08417508417508607,
#   '10': 0.08418182896541576,
#   'text': 'Facebook secretly deleted messages Mark Zuckerberg sent on Messenger #privacy #dataprotection https://t.co/mBF79JNaBz'},
#  {'0': 0.22834230866671196,
#   '1': 0.07102272727276715,
#   '2': 0.08671077997059636,
#   '3': 0.08664772727277009,
#   '4': 0.22834230866671196,
#   '5': 0.07594037113500676,
#   '6': 0.07435528679429308,
#   '7': 0.08664772727274621,
#   '8': 0.07102272727276715,
#   '9': 0.12037017659132067,
#   '10': 0.09894016775102067,
#   'text': '@Ruksane @sku_dra Varbt di?\nQuickly delete multiple Facebook messages in Chrome\nInstead of deleting messages one https://t.co/UGtsE4mCUD'},
#  {'0': 0.24587248485064697,
#   '1': 0.08264462809917504,
#   '2': 0.08264462809917504,
#   '3': 0.08264462809917504,
#   '4': 0.24587248485064697,
#   '5': 0.08264462809917504,
#   '6': 0.08264462809917504,
#   '7': 0.08264462809917504,
#   '8': 0.08264462809917504,
#   '9': 0.09297049035595276,
#   '10': 0.08264462809917504,
#   'text': 'Surprise your man with 6-months of totally #FREE #AmazonPrimeVideo https://t.co/VdYOcKihmw  You = 6-months of https://t.co/oYPvGeUjqU'},
#  {'0': 0.24081016520322956,
#   '1': 0.09139194330997213,
#   '2': 0.08699106144187624,
#   '3': 0.11722140102945729,
#   '4': 0.24081016520322956,
#   '5': 0.07618773727337222,
#   '6': 0.07102272727273998,
#   '7': 0.08630439310360435,
#   '8': 0.07102272727273998,
#   '9': 0.07172379057708805,
#   '10': 0.08732405351592017,
#   'text': 'GSR did have one-time API access to a random sample of public tweets from a five-month period from December 2014 to https://t.co/T70D62rQZt'},
#  {'0': 0.226695937064048,
#   '1': 0.07575757575758285,
#   '2': 0.07575757575758285,
#   '3': 0.09242424242424635,
#   '4': 0.226695937064048,
#   '5': 0.10909090909090509,
#   '6': 0.08786439181093247,
#   '7': 0.08005218418557183,
#   '8': 0.07575757575758285,
#   '9': 0.09920380788907693,
#   '10': 0.0773958002624708,
#   'text': "Will the committee on 'screen use and young people's health' talk about the impact #CambridgeAnalytica had on young vulnerable people?"},
#  {'0': 0.229314810156581,
#   '1': 0.08116883116884482,
#   '2': 0.09901681576748722,
#   '3': 0.08116883116884482,
#   '4': 0.229314810156581,
#   '5': 0.08116883116884482,
#   '6': 0.08116883116884482,
#   '7': 0.08117798942734787,
#   '8': 0.08116883116884482,
#   '9': 0.10280550554651946,
#   '10': 0.08184072325784025,
#   'text': "Facebook bug secretly unblocked people you thought you'd blocked https://t.co/wmEl944CPS #Social #Facebook #Privacy"},
#  {'0': 0.22570532915349417,
#   '1': 0.07836990595612879,
#   '2': 0.07836990595612879,
#   '3': 0.07836990595612879,
#   '4': 0.22570532915349417,
#   '5': 0.09561128526647508,
#   '6': 0.07836990595612879,
#   '7': 0.11269985650878867,
#   '8': 0.07836990595612879,
#   '9': 0.09576409333446934,
#   '10': 0.07836990595612879,
#   'text': "At #DCMS, Schroepfer struggling to account for why Facebook discovered data breach from Kogan's app 3yrs ago and on https://t.co/7jxF4AHCFL"},
#  {'0': 0.22570532915344965,
#   '1': 0.07836990595612958,
#   '2': 0.09085631576830276,
#   '3': 0.08444821591255677,
#   '4': 0.22570532915344965,
#   '5': 0.07836990595612958,
#   '6': 0.07836990595612958,
#   '7': 0.09428794480822035,
#   '8': 0.07836990595612958,
#   '9': 0.09597031908265136,
#   '10': 0.09525225145030064,
#   'text': '@Manversusbike If you have every logged into anything via Facebook it has access to your world. Facebook app on pho https://t.co/BXe1uX0eGn'},
#  {'0': 0.22570532915475133,
#   '1': 0.07836990595652588,
#   '2': 0.09890909033111253,
#   '3': 0.07836990595652588,
#   '4': 0.22570532915475133,
#   '5': 0.07836990595652588,
#   '6': 0.07839235229824877,
#   '7': 0.1095324131715109,
#   '8': 0.07836990595652588,
#   '9': 0.09561128526174702,
#   '10': 0.07836990595652588,
#   'text': 'The amount of emails I have had on privacy policies is literally annoying! 30 unread emails thanks to that https://t.co/kQMIPKVMaT'},
#  {'0': 0.24145653102782694,
#   '1': 0.09090909090855541,
#   '2': 0.07451564828627215,
#   '3': 0.09316661213518218,
#   '4': 0.24145653102782694,
#   '5': 0.07451564828627215,
#   '6': 0.07489974951281468,
#   '7': 0.09813715366804095,
#   '8': 0.08251031265636471,
#   '9': 0.07882322079860232,
#   '10': 0.0910660327200685,
#   'text': 'Really ready to delete my Facebook. Hoes always on there pointing fingers like they shit dont stank. Dick riding asses'},
#  {'0': 0.24790860413540194,
#   '1': 0.07936814487200175,
#   '2': 0.06313131313147094,
#   '3': 0.09090909090919184,
#   '4': 0.24790860413540194,
#   '5': 0.06313131313147094,
#   '6': 0.06313131313147094,
#   '7': 0.0829893110142466,
#   '8': 0.07259481854409486,
#   '9': 0.13229229550616842,
#   '10': 0.10454379562448185,
#   'text': 'The algorithmically enhanced #Facebook timeline acts indirectly on your social graph, in two ways: \n* hiding so https://t.co/H1fAhFsdXh'},
#  {'0': 0.22187981510018545,
#   '1': 0.09101175397933857,
#   '2': 0.07704160246537749,
#   '3': 0.07704160246537749,
#   '4': 0.22187981510018545,
#   '5': 0.07704160246537749,
#   '6': 0.07704160246537749,
#   '7': 0.07704160246537749,
#   '8': 0.0772153738900711,
#   '9': 0.07704160246537749,
#   '10': 0.14764344223814005,
#   'text': 'https://t.co/s8jrc56hAL Welllllllll not even surprised at all tbh. :|\n\nI mean literally jack could be killing toddl https://t.co/3txwxOVBvU'},
#  {'0': 0.23068370281015488,
#   '1': 0.0939907550075095,
#   '2': 0.08284089157938662,
#   '3': 0.07704160246574256,
#   '4': 0.23068370281015488,
#   '5': 0.09598077125564043,
#   '6': 0.07704160246574256,
#   '7': 0.07707044738174192,
#   '8': 0.11126702210259651,
#   '9': 0.07704160246574256,
#   '10': 0.07704160246574256,
#   'text': "If I was Mr. Zuckerberg, I'd be looking at a halving of my share price in the next couple of years, basically. https://t.co/1UfblAG35x"},
#  {'0': 0.23467552050068724,
#   '1': 0.10312789985745932,
#   '2': 0.09236417133100121,
#   '3': 0.08072377166615372,
#   '4': 0.23467552050068724,
#   '5': 0.0757575757576045,
#   '6': 0.09270901043558906,
#   '7': 0.0757575757576045,
#   '8': 0.07579458346972427,
#   '9': 0.09248431351754403,
#   '10': 0.07660557770663207,
#   'text': 'Are you telling me that China, a country of billionaires, where the private economy accounts for 80% of all jobs, w https://t.co/vXsz4SlVoJ'},
#  {'0': 0.2278545730166766,
#   '1': 0.08576329331046563,
#   '2': 0.08576329331046563,
#   '3': 0.08576329331046563,
#   '4': 0.2278545730166766,
#   '5': 0.08576329331046563,
#   '6': 0.08576329331046563,
#   '7': 0.08576329331046563,
#   '8': 0.08603908049959827,
#   '9': 0.08576329331046563,
#   '10': 0.08576329331046563,
#   'text': 'Facebook account has been permanently deleted.  Goodbye Facebook #DeleteFacebook'},
#  {'0': 0.22159346564385995,
#   '1': 0.07974481658694565,
#   '2': 0.07974481658694565,
#   '3': 0.0798402909306003,
#   '4': 0.22159346564385995,
#   '5': 0.09695526653569962,
#   '6': 0.07974481658694565,
#   '7': 0.08007822628729207,
#   '8': 0.07974481658694565,
#   '9': 0.12216678148464376,
#   '10': 0.08038670277012162,
#   'text': 'The number of people searching how to delete Facebook online doubled in March - with Londoners most likely to wan https://t.co/LKAnAb820L'},
#  {'0': 0.2263462739474345,
#   '1': 0.07654195981132465,
#   '2': 0.09241257332612968,
#   '3': 0.08441100345424954,
#   '4': 0.2263462739474345,
#   '5': 0.08563095793834413,
#   '6': 0.08377081472506478,
#   '7': 0.10051290662706182,
#   '8': 0.08211516824477394,
#   '9': 0.07575757575783834,
#   '10': 0.09250076616777857,
#   'text': 'Germans and their privacy-oriented super mysterious Facebook aliases. getting friend requests like who tf is this p https://t.co/WQmUtfAj11'},
#  {'0': 0.21656698051471113,
#   '1': 0.10504119534772056,
#   '2': 0.09242424242479075,
#   '3': 0.09242424242412425,
#   '4': 0.21656698051471113,
#   '5': 0.07575757575802794,
#   '6': 0.09242424242479298,
#   '7': 0.07575757575802794,
#   '8': 0.09242424241958765,
#   '9': 0.07679978989194389,
#   '10': 0.080379913036273,
#   'text': "@wef Honestly, I couldn't care less about #Zuckerberg's staggeringly late realizations.\n\n#DeleteYourFacebookAccount https://t.co/nFVrePdlN6"},
#  {'0': 0.23320573476769457,
#   '1': 0.07705969445288681,
#   '2': 0.09242424242423104,
#   '3': 0.07576475441618269,
#   '4': 0.23320573476769457,
#   '5': 0.0924509604973509,
#   '6': 0.10908373043234414,
#   '7': 0.07575757575759741,
#   '8': 0.07604037978329939,
#   '9': 0.09245535171081554,
#   '10': 0.07575757575759741,
#   'text': 'Safer alternatives to Facebook ! \nhttps://t.co/XRmMKCg5lY\n\nFind me on Minds, may be on others later.  https://t.co/0FYQZwdM7B'},
#  {'0': 0.22189036849480492,
#   '1': 0.08116883116883242,
#   '2': 0.1106889529268781,
#   '3': 0.08681074472587139,
#   '4': 0.22189036849480492,
#   '5': 0.0880039290474799,
#   '6': 0.08116883116883242,
#   '7': 0.0817210815680322,
#   '8': 0.08116883116883242,
#   '9': 0.08547950673300596,
#   '10': 0.0818989229974302,
#   'text': 'I logged into Facebook for the first time in a month and saw people that thought typing BFF is an indicator of th https://t.co/wqQbZsruMN'},
#  {'0': 0.25107003110344234,
#   '1': 0.0797086372349516,
#   '2': 0.0956112852664552,
#   '3': 0.07836990595611683,
#   '4': 0.25107003110344234,
#   '5': 0.08614923134811012,
#   '6': 0.07836990595611683,
#   '7': 0.07836990595611683,
#   '8': 0.0956112852664566,
#   '9': 0.07836990595611683,
#   '10': 0.07836990595611683,
#   'text': '@mikko @vornaskotti @5ean5ullivan Actually you can delete your facebook account (not just deactivate it)\nI found th https://t.co/uyYMARfQaZ'},
#  {'0': 0.22107244739569548,
#   '1': 0.13290396488131392,
#   '2': 0.08160815493055429,
#   '3': 0.06937402307509156,
#   '4': 0.22107244739569548,
#   '5': 0.08666453449049161,
#   '6': 0.0668449197865648,
#   '7': 0.08503649137768232,
#   '8': 0.11896055474405356,
#   '9': 0.07068998953198777,
#   '10': 0.0668449197865648,
#   'text': '@TomLondon6 Cambridge Analytica scandal and brexit are both evidence of an attempt to end democracy, the privatizat https://t.co/dkOxN0VP3r'},
#  {'0': 0.23262421722287224,
#   '1': 0.0770416024653369,
#   '2': 0.0770416024653369,
#   '3': 0.0770416024653369,
#   '4': 0.23262421722287224,
#   '5': 0.0770416024653369,
#   '6': 0.0770416024653369,
#   '7': 0.09484582150201155,
#   '8': 0.11021293912883673,
#   '9': 0.0770416024653369,
#   '10': 0.10006740735425815,
#   'text': 'You know when someone takes your nice well-meaning idea in a meeting and turns it into something shit and adds load https://t.co/NxlSpOcyBt'},
#  {'0': 0.22038683296272915,
#   '1': 0.08264462809918348,
#   '2': 0.08264462809918348,
#   '3': 0.08264462809918348,
#   '4': 0.22038683296272915,
#   '5': 0.10082644628089607,
#   '6': 0.08264462809918348,
#   '7': 0.08264462809918348,
#   '8': 0.09199408228160143,
#   '9': 0.08315794706609299,
#   '10': 0.090411550912763,
#   'text': 'Final Facebook is off my phone, and my battery life is already lasting longer :)\n\n#DeleteFacebook'},
#  {'0': 0.21983471074377975,
#   '1': 0.08264462809917685,
#   '2': 0.10080247562767748,
#   '3': 0.08264462809917685,
#   '4': 0.21983471074377975,
#   '5': 0.08264462809917685,
#   '6': 0.08264462809917685,
#   '7': 0.08264462809917685,
#   '8': 0.08264462809917685,
#   '9': 0.1008504169343049,
#   '10': 0.08264462809917685,
#   'text': "#samsung why can't I delete Facebook permanently from my S8 phone? Stop forcing Facebook on me! Let us Delete this https://t.co/ajKNC0QdAb"},
#  {'0': 0.24766667640785867,
#   '1': 0.07046526584088836,
#   '2': 0.11096256684436948,
#   '3': 0.09098419951735166,
#   '4': 0.24766667640785867,
#   '5': 0.06684491978615353,
#   '6': 0.06687508574058472,
#   '7': 0.08020251094718836,
#   '8': 0.12566844919789766,
#   '9': 0.07213711473964951,
#   '10': 0.06819321097805806,
#   'text': 'Through #Facebook you can upload a list of emails of specific users, for instance newsletter subscribers or sign up https://t.co/FEZgdRxmY7'},
#  {'0': 0.22147583151188757,
#   '1': 0.08264462809919691,
#   '2': 0.08264462809919691,
#   '3': 0.08264462809919691,
#   '4': 0.22147583151188757,
#   '5': 0.08264462809919691,
#   '6': 0.08264462809919691,
#   '7': 0.08264462809919691,
#   '8': 0.11589941905872646,
#   '9': 0.08264462809919691,
#   '10': 0.08411235273500763,
#   'text': 'Zuckerberg wasnt being honest about being dishonest. Color me surprised  \n\n#DeleteFacebook https://t.co/gsrtM7Duus'},
#  {'0': 0.21649793047960153,
#   '1': 0.08116883116894404,
#   '2': 0.09194915071654923,
#   '3': 0.08761989001381751,
#   '4': 0.21649793047960153,
#   '5': 0.09268310473172972,
#   '6': 0.08116883116894404,
#   '7': 0.08179459563363282,
#   '8': 0.09908195921826381,
#   '9': 0.08594691492831834,
#   '10': 0.08208879194019904,
#   'text': 'Do people actually care about how much data hovers up about them https://t.co/2J0mLiiyU7. Cause it scares the shit out of me.'},
#  {'0': 0.2194293523235164,
#   '1': 0.08417508417524783,
#   '2': 0.08417508417524783,
#   '3': 0.08417508417524783,
#   '4': 0.2194293523235164,
#   '5': 0.10269360269186069,
#   '6': 0.08417508417524783,
#   '7': 0.08417508417524783,
#   '8': 0.08417508417524783,
#   '9': 0.08784359618492206,
#   '10': 0.0849829437482138,
#   'text': 'Encase people do not know, I deleted my #Facebook account almost a https://t.co/PaGPURgwwZ'},
#  {'0': 0.21590909090908184,
#   '1': 0.08116883116883343,
#   '2': 0.09901014901180619,
#   '3': 0.09531631186277535,
#   '4': 0.21590909090908184,
#   '5': 0.08116883116883343,
#   '6': 0.09902597402597317,
#   '7': 0.08116883116883343,
#   '8': 0.08116883116883343,
#   '9': 0.08118465618299828,
#   '10': 0.08487849333203142,
#   'text': 'Facebook can still track you even after you delete your account | Daily Mail Online https://t.co/ZOldRJsECm via @pinterest'},
#  {'0': 0.21590909090906799,
#   '1': 0.09899325174618298,
#   '2': 0.08606380473271201,
#   '3': 0.08315441601523814,
#   '4': 0.21590909090906799,
#   '5': 0.08116883116886367,
#   '6': 0.08116883116886367,
#   '7': 0.09214541561578982,
#   '8': 0.09902597402573554,
#   '9': 0.08116883116886367,
#   '10': 0.08120155344868256,
#   'text': 'Us too. Or stripped the account of data and connections as we still authenticate elsewhere with it for now. Faceboo https://t.co/13qdmMNlVA'},
#  {'0': 0.2255707963004654,
#   '1': 0.09036167816600196,
#   '2': 0.08116883116883433,
#   '3': 0.08116883116883433,
#   '4': 0.2255707963004654,
#   '5': 0.08116883116883433,
#   '6': 0.08116883116883433,
#   '7': 0.08883375789388079,
#   '8': 0.0990259740259591,
#   '9': 0.08983312702880722,
#   '10': 0.0816993419095482,
#   'text': '.@zeynep on the money again &gt; Why Zuckerbergs 14-Year Apology Tour Hasnt Fixed Facebook https://t.co/1YVrs4A70W via @WIRED'},
#  {'0': 0.21677097619395952,
#   '1': 0.08842331979732809,
#   '2': 0.09381483598906384,
#   '3': 0.07102272727344097,
#   '4': 0.21677097619395952,
#   '5': 0.09066745211834822,
#   '6': 0.07102272727344097,
#   '7': 0.11762970463826011,
#   '8': 0.0866477272735816,
#   '9': 0.07727102037765961,
#   '10': 0.08672950906491701,
#   'text': "I'm still waiting for the link to #CambridgeAnalytica when the #Skirpals finally give public testimony...which they https://t.co/rMmY97rjxR"},
#  {'0': 0.2051512384910799,
#   '1': 0.07332266686867007,
#   '2': 0.10549426291769559,
#   '3': 0.08944281524930388,
#   '4': 0.2051512384910799,
#   '5': 0.0803447453117288,
#   '6': 0.07331378299124491,
#   '7': 0.08948139467614889,
#   '8': 0.08948182041212895,
#   '9': 0.10557184750738324,
#   '10': 0.08839542557461574,
#   'text': 'Geolocation is just one tool in this armoury, and a great way to ensure  you are delivering the right message to t https://t.co/QLWvFD8o6H'},
#  {'0': 0.21383069927196038,
#   '1': 0.10003562501984503,
#   '2': 0.08264462809919931,
#   '3': 0.08343544936008918,
#   '4': 0.21383069927196038,
#   '5': 0.10080258438264508,
#   '6': 0.08266848999756798,
#   '7': 0.08264462809919931,
#   '8': 0.08264462809919931,
#   '9': 0.08264462809919931,
#   '10': 0.08864863957109496,
#   'text': 'Facebook Conference (F8) feels like a joke every year, specially after Cambridge Analytica.'},
#  {'0': 0.2615220915048774,
#   '1': 0.15281668530034556,
#   '2': 0.08812945323879533,
#   '3': 0.07438059444968276,
#   '4': 0.2615220915048774,
#   '5': 0.08036890645587894,
#   '6': 0.0658761528326943,
#   '7': 0.07002791935023911,
#   '8': 0.06589214210401961,
#   '9': 0.06912158992459726,
#   '10': 0.07186446483886995,
#   'text': 'FACT CHECK: Is Facebook Removing the Share Button from Pro-Trump Posts? https://t.co/zeiv0eZM3K As usual, Senator T https://t.co/Oq5Ap6nWdn'},
#  {'0': 0.21542237822501797,
#   '1': 0.08417508417508897,
#   '2': 0.08417508417508897,
#   '3': 0.08417508417508897,
#   '4': 0.21542237822501797,
#   '5': 0.08417508417508897,
#   '6': 0.08417508417508897,
#   '7': 0.08417508417508897,
#   '8': 0.10238083368216301,
#   '9': 0.08471824326731386,
#   '10': 0.09242803977497126,
#   'text': "Delete your curious cat account (or not) it's your life not mine https://t.co/qskdxDD93s"},
#  {'0': 0.2065073802516426,
#   '1': 0.10923597348657745,
#   '2': 0.07575757575791509,
#   '3': 0.07584230848602215,
#   '4': 0.2065073802516426,
#   '5': 0.07575962611276282,
#   '6': 0.08319164987927813,
#   '7': 0.07828523952785224,
#   '8': 0.10908677280106488,
#   '9': 0.09256325015856852,
#   '10': 0.09377022353831611,
#   'text': "@withorpe @June4th Either the gov't, is plain fuking stupid or they must get a net return from taxing the people wh https://t.co/VZYP5HMNuS"},
#  {'0': 0.2337043007201033,
#   '1': 0.06493506493515583,
#   '2': 0.07799587981220982,
#   '3': 0.08033675253079042,
#   '4': 0.2337043007201033,
#   '5': 0.06671778120878809,
#   '6': 0.06493506493515583,
#   '7': 0.06984100792478479,
#   '8': 0.07995555234966159,
#   '9': 0.12584683719151432,
#   '10': 0.13573175839183607,
#   'text': 'Very  interesting interview and basically agree with his points . For me Facebook is the worst social media out the https://t.co/YR3rJlZd7L'},
#  {'0': 0.21980845450416017,
#   '1': 0.09556419494991604,
#   '2': 0.08426678060549118,
#   '3': 0.07836990595612472,
#   '4': 0.21980845450416017,
#   '5': 0.07885581509942528,
#   '6': 0.07836990595612472,
#   '7': 0.08536852970827942,
#   '8': 0.09565837558300218,
#   '9': 0.09617080167846366,
#   '10': 0.08756723595901256,
#   'text': 'My aunt and uncle deleted me on Facebook and made my cousins delete me because I shared something pro choice lol'},
#  {'0': 0.22570532915352087,
#   '1': 0.09561128526646864,
#   '2': 0.07836990595613116,
#   '3': 0.07836990595613116,
#   '4': 0.22570532915352087,
#   '5': 0.11285266457677506,
#   '6': 0.07836990595613116,
#   '7': 0.07836990595613116,
#   '8': 0.09561128526644842,
#   '9': 0.07836990595613116,
#   '10': 0.07836990595613116,
#   'text': "@simple_season There's a protest when he's visiting the UK 12th-13th-14th July, with coaches going from all over th https://t.co/PtSti7QNAX"},
#  {'0': 0.21823711617563357,
#   '1': 0.07836990595611476,
#   '2': 0.14730944268301163,
#   '3': 0.07836990595611476,
#   '4': 0.21823711617563357,
#   '5': 0.07836990595611476,
#   '6': 0.07836990595611476,
#   '7': 0.08577279941661596,
#   '8': 0.07836990595611476,
#   '9': 0.0783794998394147,
#   '10': 0.07845161210475031,
#   'text': "So finally Facebook admits tracking users, even if they're logged out or dont even have a Facebook account\nhttps://t.co/k0kbu9GnD8 #privacy"},
#  {'0': 0.20821272721518647,
#   '1': 0.11285266457651516,
#   '2': 0.09561128526148174,
#   '3': 0.07836990595663905,
#   '4': 0.20821272721518647,
#   '5': 0.07836990595663905,
#   '6': 0.07836990595663905,
#   '7': 0.07836990595663905,
#   '8': 0.07862112858606422,
#   '9': 0.0960405876177368,
#   '10': 0.09518198291645938,
#   'text': "Facts! Let's stop pretending Toby Maguire was any good and permanently delete Spiderman 2 and 3 - Derek https://t.co/ikS2Hi3hDT"},
#  {'0': 0.20699442176272306,
#   '1': 0.07983943403677346,
#   '2': 0.15938471520365416,
#   '3': 0.07836990595615906,
#   '4': 0.20699442176272306,
#   '5': 0.07836990595615906,
#   '6': 0.07836990595615906,
#   '7': 0.07836990595615906,
#   '8': 0.08349363937432809,
#   '9': 0.07843825984172582,
#   '10': 0.07836990595615906,
#   'text': 'BBC News - Facebook seeks facial recognition consent in EU and Canada https://t.co/RiqhaRhF7a &gt;DELETE YOUR ACCOUNT https://t.co/XryuqR4Qaz'},
#  {'0': 0.22022382608963026,
#   '1': 0.09985886491426976,
#   '2': 0.06887717840578032,
#   '3': 0.0688705234167734,
#   '4': 0.22022382608963026,
#   '5': 0.09059998672077155,
#   '6': 0.0688705234167734,
#   '7': 0.11547495310323706,
#   '8': 0.11432506887163904,
#   '9': 0.06887703649291443,
#   '10': 0.08402203856821074,
#   'text': 'I have just contacted #yahoo to complain about the spectacularly intensive advertising campaign they are running vi https://t.co/BrmItu9ner'},
#  {'0': 0.19938647259815573,
#   '1': 0.14311300320130316,
#   '2': 0.07102272727274543,
#   '3': 0.07363125457243164,
#   '4': 0.19938647259815573,
#   '5': 0.09961192271399569,
#   '6': 0.07102272727274543,
#   '7': 0.07165322692348136,
#   '8': 0.10229176320070843,
#   '9': 0.09640784833879931,
#   '10': 0.07185905390563374,
#   'text': '@bloonface @dewordepolitics @clfinnecy @loftandlost @BradipoWayway @Bi99le5 added to this he could talk about Cambr https://t.co/tsOIIutcKA'},
#  {'0': 0.21005698508849827,
#   '1': 0.0839187722914626,
#   '2': 0.07451564828616065,
#   '3': 0.09090909090911506,
#   '4': 0.21005698508849827,
#   '5': 0.11702108416227101,
#   '6': 0.07452176353105347,
#   '7': 0.07451564828616065,
#   '8': 0.07451564828616065,
#   '9': 0.1094604659895654,
#   '10': 0.09056489316955227,
#   'text': "So, today is a big day for me  \n\nYes, I'm quitting #Facebook. No one ever bothers to speak to me on there anyway s https://t.co/nWptNalKqe"},
#  {'0': 0.21300659621873982,
#   '1': 0.08664772727314825,
#   '2': 0.10915715249405519,
#   '3': 0.07102272727308313,
#   '4': 0.21300659621873982,
#   '5': 0.09501647860523067,
#   '6': 0.07111561726748938,
#   '7': 0.0711289470556433,
#   '8': 0.10220066762791284,
#   '9': 0.09418340904325126,
#   '10': 0.08652067714144611,
#   'text': 'I must say, since I deleted #Facebook and deactivated my account it has given me more time to myself. Previously ha https://t.co/lSTcUHsspF'},
#  {'0': 0.20667127267394741,
#   '1': 0.10342851507622958,
#   '2': 0.07974481658699126,
#   '3': 0.07974481658699126,
#   '4': 0.20667127267394741,
#   '5': 0.07974481658699126,
#   '6': 0.07974481658699126,
#   '7': 0.07975580904085446,
#   '8': 0.09728867623601009,
#   '9': 0.11413164403800213,
#   '10': 0.07974481658699126,
#   'text': 'My #colleague left his #Facebook signed in on my browser so I took the liberty of #reading his messages for him . https://t.co/ZOc2IuDtvl'},
#  {'0': 0.22558917057196354,
#   '1': 0.0811688311688422,
#   '2': 0.0811688311688422,
#   '3': 0.08168336652104873,
#   '4': 0.22558917057196354,
#   '5': 0.0811688311688422,
#   '6': 0.09851143867377718,
#   '7': 0.0811802449005134,
#   '8': 0.0811688311688422,
#   '9': 0.0992928969616426,
#   '10': 0.0890675576956858,
#   'text': "Doesn't look like my Facebook date was used as I'm assured neither me nor my FB friends logged into My Digital Life https://t.co/4RCVwe5sY4"},
#  {'0': 0.2132867132831656,
#   '1': 0.08741258741298158,
#   '2': 0.08741258741298158,
#   '3': 0.08741258741298158,
#   '4': 0.2132867132831656,
#   '5': 0.08741258741298158,
#   '6': 0.08741258741298158,
#   '7': 0.08741258741298158,
#   '8': 0.08741258741298158,
#   '9': 0.08741258741298158,
#   '10': 0.08741258741298158,
#   'text': 'Senator Hatch is a better lobbyist for Mark Zuckerberg than Mark Zuckerberg. There are always tradeoffs.'},
#  {'0': 0.2099769416931157,
#   '1': 0.0841750841750856,
#   '2': 0.0841750841750856,
#   '3': 0.0841750841750856,
#   '4': 0.2099769416931157,
#   '5': 0.0841750841750856,
#   '6': 0.08421544022887795,
#   '7': 0.0841750841750856,
#   '8': 0.08447714323982101,
#   '9': 0.11548231129809788,
#   '10': 0.0849727426646595,
#   'text': 'These people are simply not to be trusted https://t.co/KiFHpXL0cG #DeleteFacebook'},
#  {'0': 0.21317924586548348,
#   '1': 0.08741258741259125,
#   '2': 0.08752005483378641,
#   '3': 0.08741258741259125,
#   '4': 0.21317924586548348,
#   '5': 0.08741258741259125,
#   '6': 0.08741258741259125,
#   '7': 0.08741258741259125,
#   '8': 0.08741258741259125,
#   '9': 0.08741258741259125,
#   '10': 0.08741258741259125,
#   'text': 'WAIT WHAT ABOUT THE T-SHIRT https://t.co/jPbxLKpFfC'},
#  {'0': 0.22464430524535894,
#   '1': 0.09902597402597627,
#   '2': 0.0990259740259767,
#   '3': 0.0811688311688361,
#   '4': 0.22464430524535894,
#   '5': 0.08990977250430346,
#   '6': 0.0811688311688361,
#   '7': 0.0811688311688361,
#   '8': 0.0811688311688361,
#   '9': 0.08154981835420405,
#   '10': 0.0811688311688361,
#   'text': '@rapplerdotcom as @facebooks fact checker? #Rappler needs fact checking itself. But well, if that day comes, Ill https://t.co/aj0sUpqOC3'},
#  {'0': 0.21302388886741797,
#   '1': 0.08741258741258956,
#   '2': 0.08741258741258956,
#   '3': 0.08741258741258956,
#   '4': 0.21302388886741797,
#   '5': 0.08741258741258956,
#   '6': 0.08741258741258956,
#   '7': 0.08741258741258956,
#   '8': 0.08746926409003522,
#   '9': 0.08741258741258956,
#   '10': 0.0876187351544198,
#   'text': "I bet he's shitting himself https://t.co/mDEjmvkeO3"},
#  {'0': 0.20534851483377692,
#   '1': 0.08109415735113944,
#   '2': 0.08142141678651249,
#   '3': 0.08234385145645477,
#   '4': 0.20534851483377692,
#   '5': 0.08607610372831362,
#   '6': 0.07974481658693389,
#   '7': 0.1041933367778512,
#   '8': 0.07974481658693389,
#   '9': 0.10274430965602988,
#   '10': 0.0972886762360539,
#   'text': 'Mr. Zuckerberg...if I forget my wifi password, can I just restart it to set a new one? Or do I have to call the cab https://t.co/EOLaZxRpju'},
#  {'0': 0.21107272134220478,
#   '1': 0.08963813303026474,
#   '2': 0.08005165220781732,
#   '3': 0.0809002683640757,
#   '4': 0.21107272134220478,
#   '5': 0.07836990595647426,
#   '6': 0.1027007347224303,
#   '7': 0.1034856520016638,
#   '8': 0.0970411204621207,
#   '9': 0.07836990595647426,
#   '10': 0.07836990595647426,
#   'text': 'No he doesnt. A suitably senior and qualified representative of the company should suffice, unless you are interes https://t.co/T8qKSUfqNm'},
#  {'0': 0.20356349915779917,
#   '1': 0.09728867623639492,
#   '2': 0.07974481658731399,
#   '3': 0.07974481658731399,
#   '4': 0.20356349915779917,
#   '5': 0.07974481658731399,
#   '6': 0.07974481658731399,
#   '7': 0.08802782748190673,
#   '8': 0.08001951865676998,
#   '9': 0.09728867623649363,
#   '10': 0.1148325358813796,
#   'text': '#DeleteFacebook everybody. Seriously #DeleteFacebookNow\n\n+\nDoes #fakebook indirectly contribute to #suicide and https://t.co/jox1uJkWd3'},
#  {'0': 0.198246163963297,
#   '1': 0.07472362812615481,
#   '2': 0.09087455138703168,
#   '3': 0.09098897884444994,
#   '4': 0.198246163963297,
#   '5': 0.08011679309414424,
#   '6': 0.07451564828617191,
#   '7': 0.1179257666465282,
#   '8': 0.07451564828617191,
#   '9': 0.10713919239303853,
#   '10': 0.09095362897301183,
#   'text': '#Facebook was warned by security researchers that attackers could abuse its phone number and email search facility https://t.co/pCsEPIeiVi'},
#  {'0': 0.19844501233000936,
#   '1': 0.07836368486679672,
#   '2': 0.09090909090948189,
#   '3': 0.11249225371116908,
#   '4': 0.19844501233000936,
#   '5': 0.09705577963405745,
#   '6': 0.10187942546151023,
#   '7': 0.0847624021848961,
#   '8': 0.07451564828646529,
#   '9': 0.07451564828646529,
#   '10': 0.08706105432914862,
#   'text': 'Downplaying the number of accounts affected by Cambridge Analytica by mentioning only the first degree accounts :  https://t.co/54UgpYti5u'},
#  {'0': 0.20926243567753086,
#   '1': 0.0857632933104661,
#   '2': 0.0857632933104661,
#   '3': 0.0857632933104661,
#   '4': 0.20926243567753086,
#   '5': 0.0858449346441963,
#   '6': 0.0857632933104661,
#   '7': 0.10454957650501003,
#   '8': 0.0857632933104661,
#   '9': 0.0857632933104661,
#   '10': 0.0857632933104661,
#   'text': "Mark Zuckerberg says it'll take three years to 'fix' Facebook - CNET  https://t.co/Mfh45RFa5u"},
#  {'0': 0.20926243567752542,
#   '1': 0.0857632933104642,
#   '2': 0.0857632933104642,
#   '3': 0.0857632933104642,
#   '4': 0.20926243567752542,
#   '5': 0.0857632933104642,
#   '6': 0.0857632933104642,
#   '7': 0.0857632933104642,
#   '8': 0.0857632933104642,
#   '9': 0.1046312178387608,
#   '10': 0.0857632933104642,
#   'text': '#Facebook is shutting down a teen app it bought eight months ago https://t.co/kogEDUE7E4'},
#  {'0': 0.20926243567752767,
#   '1': 0.08576329331048375,
#   '2': 0.08627360420366278,
#   '3': 0.08576329331048375,
#   '4': 0.20926243567752767,
#   '5': 0.0937259144327761,
#   '6': 0.08576329331048375,
#   '7': 0.09615828582313088,
#   '8': 0.08576329331048375,
#   '9': 0.08576329331048375,
#   '10': 0.08576329331048375,
#   'text': "Fucking Hina, trying to negotiate my cat's account. Bitch, we're taking this to Mark Zuckerberg https://t.co/yMUcltxCF1"},
#  {'0': 0.20926243567505481,
#   '1': 0.08576329331129227,
#   '2': 0.08576329331129227,
#   '3': 0.08576329331129227,
#   '4': 0.20926243567505481,
#   '5': 0.08576329331129227,
#   '6': 0.08576329331129227,
#   '7': 0.08576329331129227,
#   '8': 0.08576329331129227,
#   '9': 0.08576329331129227,
#   '10': 0.1046312178346069,
#   'text': '#DeleteFacebook if you dare. You can! Sehr lesenswerter Artikel. @greiten  https://t.co/3bzlBN7lHt'},
#  {'0': 0.20924925180862122,
#   '1': 0.08577647717970875,
#   '2': 0.08576329331056358,
#   '3': 0.08576329331056358,
#   '4': 0.20924925180862122,
#   '5': 0.08576329331056358,
#   '6': 0.08576329331056358,
#   '7': 0.08576329331056358,
#   '8': 0.08576329331056358,
#   '9': 0.10463121783772499,
#   '10': 0.08576329331056358,
#   'text': "After all man means person really, right? #everydaysexism #bbcnews - Zuckerberg: I'm still the man to run Facebook https://t.co/AZEFUWtiLW"},
#  {'0': 0.20923249397444804,
#   '1': 0.08576329331046978,
#   '2': 0.08576329331046978,
#   '3': 0.08576329331046978,
#   '4': 0.20923249397444804,
#   '5': 0.08576607317458647,
#   '6': 0.08576584160049174,
#   '7': 0.08576329331046978,
#   '8': 0.10462588968463349,
#   '9': 0.08576329331046978,
#   '10': 0.08579323501349136,
#   'text': 'https://t.co/hPVdDoxDNk apparently, Facebook should be broken up - erm, how would that work?'},
#  {'0': 0.21328671328669796,
#   '1': 0.0874125874125891,
#   '2': 0.0874125874125891,
#   '3': 0.0874125874125891,
#   '4': 0.21328671328669796,
#   '5': 0.0874125874125891,
#   '6': 0.0874125874125891,
#   '7': 0.0874125874125891,
#   '8': 0.0874125874125891,
#   '9': 0.0874125874125891,
#   '10': 0.0874125874125891,
#   'text': '#Zuckerberg reminds me of Titians Vandramin Family @gleniculate https://t.co/jxIJXIVS1L'},
#  {'0': 0.250491992120373,
#   '1': 0.07575757575760929,
#   '2': 0.08741643936472777,
#   '3': 0.07982125602410434,
#   '4': 0.250491992120373,
#   '5': 0.09558698757668116,
#   '6': 0.09078620582945081,
#   '7': 0.08568910914941984,
#   '8': 0.07575757575760929,
#   '9': 0.08292820516006277,
#   '10': 0.07576465325996162,
#   'text': '@rachelcoldicutt I can give refugees data top-ups for their phones via a Facebook group, so they can talk to their https://t.co/vl8rJ13mba'},
#  {'0': 0.23531481819962152,
#   '1': 0.07836990595614703,
#   '2': 0.07836990595614703,
#   '3': 0.07919772803224204,
#   '4': 0.23531481819962152,
#   '5': 0.11680415292158816,
#   '6': 0.07836990595614703,
#   '7': 0.07836990595614703,
#   '8': 0.09033368002180917,
#   '9': 0.07887243923247,
#   '10': 0.08599755776768107,
#   'text': "Life size cutouts were displayed on Capitol Hill by an advocacy group wearing Fix Fakebook ahead of Zuckerberg's https://t.co/VoCjo2lsqU"},
#  {'0': 0.20894147798444726,
#   '1': 0.0857632933104649,
#   '2': 0.0857632933104649,
#   '3': 0.1046312178387516,
#   '4': 0.20894147798444726,
#   '5': 0.0857632933104649,
#   '6': 0.0857632933104649,
#   '7': 0.0857632933104649,
#   '8': 0.08608425100354694,
#   '9': 0.0857632933104649,
#   '10': 0.0857632933104649,
#   'text': 'Most effective #DeleteFacebook message ever. https://t.co/kpr5UNZISR'},
#  {'0': 0.24048541200968357,
#   '1': 0.14002140031939295,
#   '2': 0.10226602631163004,
#   '3': 0.07106311496551797,
#   '4': 0.24048541200968357,
#   '5': 0.07818460846204267,
#   '6': 0.07102272727278619,
#   '7': 0.07111979722906692,
#   '8': 0.07102272727278619,
#   '9': 0.07404747281856928,
#   '10': 0.08076671333852428,
#   'text': 'Must be mental for Mark Zuckerberg.. one day hes at college fannying about with a new website for his pals and the https://t.co/4V1sK9dd71'},
#  {'0': 0.1926269538260139,
#   '1': 0.1500101195070829,
#   '2': 0.08533514725985214,
#   '3': 0.06993006993048953,
#   '4': 0.1926269538260139,
#   '5': 0.08531468531518761,
#   '6': 0.06993006993048953,
#   '7': 0.0853348337603245,
#   '8': 0.1006993006998997,
#   '9': 0.07367912454397232,
#   '10': 0.08713969522668781,
#   'text': '@AlexPalmerama @Madincroydon @faisalislam Funny that she believed she could delete it .. from Facebook?\n\nThe only e https://t.co/KOqW8JRka8'},
#  {'0': 0.22698076146991353,
#   '1': 0.08576329331048663,
#   '2': 0.08576329331048663,
#   '3': 0.08576329331048663,
#   '4': 0.22698076146991353,
#   '5': 0.08576329331048663,
#   '6': 0.08576329331048663,
#   '7': 0.08576329331048663,
#   '8': 0.08691289204619339,
#   '9': 0.08576329331048663,
#   '10': 0.08576329331048663,
#   'text': '@bechillcomedian Robocop, terminator, mark zuckerberg. Kiss one, marry one, kill one'},
#  {'0': 0.19394664361863834,
#   '1': 0.13564213564207855,
#   '2': 0.07538991495285521,
#   '3': 0.08993640942342752,
#   '4': 0.19394664361863834,
#   '5': 0.0880322798963856,
#   '6': 0.07215007215008667,
#   '7': 0.08444093759955283,
#   '8': 0.08802308802309844,
#   '9': 0.07215007215008667,
#   '10': 0.1002884465437902,
#   'text': '@carolecadwalla @Spookella https://t.co/xK78w91wlz \nWylie went on: I am absolutely convinced that there was a comm https://t.co/dJ9EzMdamg'},
#  {'0': 0.2001176841803185,
#   '1': 0.07836990595611552,
#   '2': 0.12167833176971354,
#   '3': 0.08382727705663981,
#   '4': 0.2001176841803185,
#   '5': 0.07836990595611552,
#   '6': 0.09508046958360906,
#   '7': 0.09621171136181833,
#   '8': 0.07836990595611552,
#   '9': 0.0789061613539312,
#   '10': 0.08906864682562288,
#   'text': 'Guardian @alexhern @carolecadwalla have revealed that This Is Your Digital Life gathered Facebook messages. Kogan https://t.co/w4U3N97N8R'},
#  {'0': 0.22417573148641814,
#   '1': 0.08417508417545755,
#   '2': 0.08417508417545755,
#   '3': 0.08419975588410872,
#   '4': 0.22417573148641814,
#   '5': 0.08417508417545755,
#   '6': 0.08422810081542596,
#   '7': 0.10227882498443318,
#   '8': 0.08417508417545755,
#   '9': 0.08417508417545755,
#   '10': 0.0842421659523262,
#   'text': 'No surprises that #GDPR and #CambridgeAnalytica feature at @PwCs #ScaleSW event! https://t.co/MwxtBKfLWu'},
#  {'0': 0.20538720538720623,
#   '1': 0.0843119479564402,
#   '2': 0.08417508417508537,
#   '3': 0.08426134459821483,
#   '4': 0.20538720538720623,
#   '5': 0.08417508417508537,
#   '6': 0.08417508417508537,
#   '7': 0.09090987342916536,
#   '8': 0.08417508417508537,
#   '9': 0.08499355557708779,
#   '10': 0.11343573635154412,
#   'text': 'What a child Zuckerberg...They told us they delete it..how stupid and naive are you..wtf?...really..ok you are no https://t.co/Cqokt6k2lX'},
#  {'0': 0.22390572390572594,
#   '1': 0.08417508417509124,
#   '2': 0.08417508417509124,
#   '3': 0.08417508417509124,
#   '4': 0.22390572390572594,
#   '5': 0.08417508417509124,
#   '6': 0.08417508417509124,
#   '7': 0.08417508417509124,
#   '8': 0.08417508417509124,
#   '9': 0.10269360269354406,
#   '10': 0.08417508417509124,
#   'text': '@Hippokloppamus It was posted on Facebook you moron delete ya tweet its totally irrelevant'},
#  {'0': 0.2053872053872148,
#   '1': 0.08417508417510508,
#   '2': 0.09441988443683741,
#   '3': 0.11036653283687084,
#   '4': 0.2053872053872148,
#   '5': 0.08417508417510508,
#   '6': 0.08417508417510508,
#   '7': 0.08477587228844644,
#   '8': 0.08417508417510508,
#   '9': 0.08417508417510508,
#   '10': 0.08417508417510508,
#   'text': 'The 2,000 Year Old Cambridge Analytica Algorithm Alive  https://t.co/3ISBw30NZe @OleryHQ @hotel_speak #insights #hospitality #Data'},
#  {'0': 0.2159645698070381,
#   '1': 0.08417508417508905,
#   '2': 0.08417508417508905,
#   '3': 0.08417508417508905,
#   '4': 0.2159645698070381,
#   '5': 0.1026936026936051,
#   '6': 0.08417508417508905,
#   '7': 0.09211623827373353,
#   '8': 0.08417508417508905,
#   '9': 0.08417508417508905,
#   '10': 0.08417508417508905,
#   'text': 'Facebook plans to let everyone unsend messages, wont let Zuckerberg until then  https://t.co/3xAT9dHjvL'},
#  {'0': 0.20538720538716804,
#   '1': 0.08417508417509469,
#   '2': 0.08417508417509469,
#   '3': 0.10269360269360117,
#   '4': 0.20538720538716804,
#   '5': 0.08417508417509469,
#   '6': 0.08417508417509469,
#   '7': 0.08417508417509469,
#   '8': 0.08417508417509469,
#   '9': 0.10269360269356795,
#   '10': 0.08417508417509469,
#   'text': "If anyone in the world is either a space lizard or secretly an android it's 100% mark zuckerberg"},
#  {'0': 0.20532961392421198,
#   '1': 0.08417508417508661,
#   '2': 0.08417508417508661,
#   '3': 0.08417508417508661,
#   '4': 0.20532961392421198,
#   '5': 0.08417508417508661,
#   '6': 0.08417508417508661,
#   '7': 0.08418794291674582,
#   '8': 0.08417508417508661,
#   '9': 0.10273833541492929,
#   '10': 0.10269360269359318,
#   'text': 'A method for predicting when our friends will die? Somebody needs to stop those creeps at #Facebook... https://t.co/YqOMMPYEwh'},
#  {'0': 0.20798041036192286,
#   '1': 0.0874125874125884,
#   '2': 0.0874125874125884,
#   '3': 0.0874125874125884,
#   '4': 0.20798041036192286,
#   '5': 0.0874125874125884,
#   '6': 0.0874125874125884,
#   '7': 0.0874125874125884,
#   '8': 0.0874125874125884,
#   '9': 0.0917382233664798,
#   '10': 0.0883932543834786,
#   'text': 'Apparently @Arron_banks hardly knew these people..... https://t.co/kAjG3EjDAc'},
#  {'0': 0.20165477347087335,
#   '1': 0.07704160246537957,
#   '2': 0.07820335343250759,
#   '3': 0.07704160246537957,
#   '4': 0.20165477347087335,
#   '5': 0.0843251116220665,
#   '6': 0.07704160246537957,
#   '7': 0.08265476020390569,
#   '8': 0.07704160246537957,
#   '9': 0.1314220367363023,
#   '10': 0.11357355467282639,
#   'text': 'Hmm.....Mark Zuckerberg wants an independent council of non-Facebookers to make the final call on removing dangerou https://t.co/PnyAOb8yhQ'},
#  {'0': 0.24143417189464272,
#   '1': 0.08417508417508762,
#   '2': 0.08417508417508762,
#   '3': 0.08417508417508762,
#   '4': 0.24143417189464272,
#   '5': 0.08417508417508762,
#   '6': 0.08417508417508762,
#   '7': 0.0850494297115432,
#   '8': 0.08417508417508762,
#   '9': 0.0842908091682008,
#   '10': 0.08417508417508762,
#   'text': '#museums #heritage adding alternative text for images on Facebook https://t.co/7BAadDVg8z'},
#  {'0': 0.18970292360024368,
#   '1': 0.17270311791320936,
#   '2': 0.06993006993053213,
#   '3': 0.07022963653643437,
#   '4': 0.18970292360024368,
#   '5': 0.08531468531523842,
#   '6': 0.06993006993053213,
#   '7': 0.07603953480576718,
#   '8': 0.10069930069996101,
#   '9': 0.0895993903949695,
#   '10': 0.0758512708731121,
#   'text': 'Dacre, Murdoch &amp; his little rat-puppet at The Sun, the ERG, Cambridge Analytica and the fetid remains of UKIP  shou https://t.co/l5EQw3ZxVU'},
#  {'0': 0.1919191919191255,
#   '1': 0.09614820022048053,
#   '2': 0.08802308802321979,
#   '3': 0.07215007215018064,
#   '4': 0.1919191919191255,
#   '5': 0.08972359243799226,
#   '6': 0.07215007215018064,
#   '7': 0.09495027973482302,
#   '8': 0.10179052799550828,
#   '9': 0.09664181178877573,
#   '10': 0.09650316357971361,
#   'text': '@Billy_Nomad_ @CommonsCMS @UKParliament @chrisinsilico @podehaye @DamianCollins @facebook A government block on https://t.co/xT6ZLax0JL'},
#  {'0': 0.2331441027037181,
#   '1': 0.0721500721508123,
#   '2': 0.11026890992685003,
#   '3': 0.0721500721508123,
#   '4': 0.2331441027037181,
#   '5': 0.10391743469869337,
#   '6': 0.0721500721508123,
#   '7': 0.0721500721508123,
#   '8': 0.08802308802383295,
#   '9': 0.0721500721508123,
#   '10': 0.10389610389284398,
#   'text': '#Facebook posted to my Linear bPad this morning with a fresco detailing our 5 years together.  It was basically a M https://t.co/A2yal0pRnr'},
#  {'0': 0.24421169061683862,
#   '1': 0.07215007215049715,
#   '2': 0.08802051643451309,
#   '3': 0.08802308802359551,
#   '4': 0.24421169061683862,
#   '5': 0.08802308802242727,
#   '6': 0.07215007215049715,
#   '7': 0.07930754234973188,
#   '8': 0.07216644720602408,
#   '9': 0.10799808941473751,
#   '10': 0.08794939363113771,
#   'text': 'If #ENG managers were #socialmedia/apps:\n \nCapello: LinkedIn (strictly business)\nMcClaren: Google+ (nobody knows ho https://t.co/lOt93Qaj0w'},
#  {'0': 0.20386826862437865,
#   '1': 0.10265293584682392,
#   '2': 0.08417508417509972,
#   '3': 0.08417508417509972,
#   '4': 0.20386826862437865,
#   '5': 0.10068610678498913,
#   '6': 0.08417508417509972,
#   '7': 0.08618258008357793,
#   '8': 0.08417508417509972,
#   '9': 0.08569402093794809,
#   '10': 0.08421575102188332,
#   'text': '@BarackObama Obama basically just said f*ck the middle-east, who cares about if they have a nuclear war. Yet when https://t.co/ZPWjIZhfco'},
#  {'0': 0.2162382841003781,
#   '1': 0.07661690710304392,
#   '2': 0.0745567316077041,
#   '3': 0.10730253353170344,
#   '4': 0.2162382841003781,
#   '5': 0.07451564828618262,
#   '6': 0.09086800758761487,
#   '7': 0.07866444035474021,
#   '8': 0.09090909090913231,
#   '9': 0.08302582298741792,
#   '10': 0.10730253353208245,
#   'text': '@Shelaco @fantasticmusic @bickypeg @RenieriArts @Cukullen @guardian @Ian56789 @2ndNewMoon @theart4peace @briangukc https://t.co/nDf0H8YkXx'},
#  {'0': 0.19506489060384594,
#   '1': 0.09242424242425343,
#   '2': 0.07708507667151454,
#   '3': 0.11196830956942275,
#   '4': 0.19506489060384594,
#   '5': 0.09242424242421114,
#   '6': 0.07575757575758724,
#   '7': 0.1138978771563499,
#   '8': 0.07580213271599132,
# ...
#   '4': 0.17482517482517698,
#   '5': 0.08741258741258849,
#   '6': 0.08741258741258849,
#   '7': 0.08741258741258849,
#   '8': 0.08741258741258849,
#   '9': 0.08741258741258849,
#   '10': 0.10664335664335528,
#   'text': "For real?...shouldn't it be illegal? https://t.co/tVgLuCAuV2"},
#  {'0': 0.17482517482517684,
#   '1': 0.08741258741258842,
#   '2': 0.08741258741258842,
#   '3': 0.08741258741258842,
#   '4': 0.17482517482517684,
#   '5': 0.08787534325035383,
#   '6': 0.08741258741258842,
#   '7': 0.08741258741258842,
#   '8': 0.08741258741258842,
#   '9': 0.12443115467930614,
#   '10': 0.08839280276963274,
#   'text': 'I think that they get things right. LOL #zuckerberg'},
#  {'0': 0.1748251748251768,
#   '1': 0.0874125874125884,
#   '2': 0.08744049906830607,
#   '3': 0.09318322630969114,
#   '4': 0.1748251748251768,
#   '5': 0.0874125874125884,
#   '6': 0.12007557532129547,
#   '7': 0.0874125874125884,
#   '8': 0.0874125874125884,
#   '9': 0.0874125874125884,
#   '10': 0.0874125874125884,
#   'text': '7 Great Applications of #MachineLearning in Pharma and Medicine https://t.co/kgqfpgF2WX   v/ @TechEmergence#AI https://t.co/kfxJquBjOs'},
#  {'0': 0.17482517482517673,
#   '1': 0.08741258741258837,
#   '2': 0.08741258741258837,
#   '3': 0.10661361588938045,
#   '4': 0.17482517482517673,
#   '5': 0.08741258741258837,
#   '6': 0.08741258741258837,
#   '7': 0.08744232816655557,
#   '8': 0.08741258741258837,
#   '9': 0.08779839297774474,
#   '10': 0.10625755107820059,
#   'text': 'Again, best analysis on Facebook! https://t.co/OFgFqQB59k'},
#  {'0': 0.17482517482517673,
#   '1': 0.0874537701502574,
#   '2': 0.08741258741258837,
#   '3': 0.08741258741258837,
#   '4': 0.17482517482517673,
#   '5': 0.08741258741258837,
#   '6': 0.10649968080745194,
#   '7': 0.08741258741258837,
#   '8': 0.10664335664335234,
#   '9': 0.08741258741258837,
#   '10': 0.0875150805108197,
#   'text': "What about 'use of buzz words' as a top AI trend? https://t.co/1clsYkpRvJ"},
#  {'0': 0.17482517482517648,
#   '1': 0.08741258741258824,
#   '2': 0.08741258741258824,
#   '3': 0.08741258741258824,
#   '4': 0.17482517482517648,
#   '5': 0.10664335664335599,
#   '6': 0.08741258741258824,
#   '7': 0.08741258741258824,
#   '8': 0.08741258741258824,
#   '9': 0.08741258741258824,
#   '10': 0.10664335664334987,
#   'text': "Watched Zuckerberg's keynote at F8. I have thoughts."},
#  {'0': 0.19405594405594323,
#   '1': 0.10664335664335106,
#   '2': 0.0874125874125882,
#   '3': 0.0874125874125882,
#   '4': 0.19405594405594323,
#   '5': 0.0874125874125882,
#   '6': 0.0874125874125882,
#   '7': 0.0874125874125882,
#   '8': 0.0874125874125882,
#   '9': 0.0874125874125882,
#   '10': 0.0874125874125882,
#   'text': 'Suspending Cambridge Analytica and SCL Group From Facebook https://t.co/I6F9XIgCpt'},
#  {'0': 0.19405594405594281,
#   '1': 0.0874125874125882,
#   '2': 0.0874125874125882,
#   '3': 0.0874125874125882,
#   '4': 0.19405594405594281,
#   '5': 0.0874125874125882,
#   '6': 0.0874125874125882,
#   '7': 0.0874125874125882,
#   '8': 0.0874125874125882,
#   '9': 0.0874125874125882,
#   '10': 0.10664335664335146,
#   'text': 'Loving this thread...  https://t.co/uoqXPytZvy'},
#  {'0': 0.17482517482517637,
#   '1': 0.09730249095257319,
#   '2': 0.08741258741258819,
#   '3': 0.08741258741258819,
#   '4': 0.17482517482517637,
#   '5': 0.08741258741258819,
#   '6': 0.08741258741258819,
#   '7': 0.10664335664335164,
#   '8': 0.08741258741258819,
#   '9': 0.09675345310336955,
#   '10': 0.08741258741258819,
#   'text': 'Easy money... https://t.co/stpWNSESk7'},
#  {'0': 0.17482517482517626,
#   '1': 0.08741258741258813,
#   '2': 0.08741258741258813,
#   '3': 0.08741258741258813,
#   '4': 0.17482517482517626,
#   '5': 0.08741258741258813,
#   '6': 0.12587412587411845,
#   '7': 0.08741258741258813,
#   '8': 0.08741258741258813,
#   '9': 0.08741258741258813,
#   '10': 0.08741258741258813,
#   'text': '#BigData Architect. - iContract ( Brighton, United Kingdom )  - [  More Info  https://t.co/6XWNPUDuGP ]  #Scala https://t.co/8Ctijzbpwz'},
#  {'0': 0.17482517482517626,
#   '1': 0.08741258741258813,
#   '2': 0.10663349362681847,
#   '3': 0.08741258741258813,
#   '4': 0.17482517482517626,
#   '5': 0.08741258741258813,
#   '6': 0.08741258741258813,
#   '7': 0.08742245042912679,
#   '8': 0.08741258741258813,
#   '9': 0.10664335664334965,
#   '10': 0.08741258741258813,
#   'text': 'Facebook on the Hill - Data Privacy Matters  https://t.co/X4iBjmaiGH'},
#  {'0': 0.17482517482517618,
#   '1': 0.08741258741258809,
#   '2': 0.12586588922143874,
#   '3': 0.08741258741258809,
#   '4': 0.17482517482517618,
#   '5': 0.08741258741258809,
#   '6': 0.08741258741258809,
#   '7': 0.08742082406526845,
#   '8': 0.08741258741258809,
#   '9': 0.08741258741258809,
#   '10': 0.08741258741258809,
#   'text': "BBC News - Facebook and You: What's The Fuss? https://t.co/BfSvBC14Gj #privacy #dataprotection #WhatHaveYouGivenAwayWithoutRealising"},
#  {'0': 0.21328671328670723,
#   '1': 0.08741258741258807,
#   '2': 0.08741258741258807,
#   '3': 0.08741258741258807,
#   '4': 0.21328671328670723,
#   '5': 0.08741258741258807,
#   '6': 0.08741258741258807,
#   '7': 0.08741258741258807,
#   '8': 0.08741258741258807,
#   '9': 0.08741258741258807,
#   '10': 0.08741258741258807,
#   'text': 'Video tips from @FalconIO   https://t.co/MC04VHLDDO'},
#  {'0': 0.17482517482517612,
#   '1': 0.08741258741258806,
#   '2': 0.105632009103052,
#   '3': 0.08741258741258806,
#   '4': 0.17482517482517612,
#   '5': 0.08741258741258806,
#   '6': 0.08741258741258806,
#   '7': 0.08741258741258806,
#   '8': 0.08741258741258806,
#   '9': 0.08741258741258806,
#   '10': 0.10765470418365548,
#   'text': '#FacebookMessenger has a new way to sell you stuff: #AugmentedReality  https://t.co/p7vfiUd5y0 #facebook https://t.co/HULPnLOa0G'},
#  {'0': 0.1748251748251761,
#   '1': 0.08741258741258805,
#   '2': 0.08741258741258805,
#   '3': 0.08741258741258805,
#   '4': 0.1748251748251761,
#   '5': 0.08856142365790237,
#   '6': 0.08741258741258805,
#   '7': 0.08741258741258805,
#   '8': 0.08741258741258805,
#   '9': 0.10664335664335188,
#   '10': 0.10549452039804147,
#   'text': 'Zuckerberg, Mueller. Why al the german namens? Fourth Reich By Jim Marrs. Yes with 2 rr s   Great Guy'},
#  {'0': 0.174825174825176,
#   '1': 0.087412587412588,
#   '2': 0.087412587412588,
#   '3': 0.087412587412588,
#   '4': 0.174825174825176,
#   '5': 0.087412587412588,
#   '6': 0.087412587412588,
#   '7': 0.087412587412588,
#   '8': 0.087412587412588,
#   '9': 0.087412587412588,
#   '10': 0.1258741258741199,
#   'text': 'A very interesting thread. #Facebook https://t.co/UDehMvJRGc'},
#  {'0': 0.174825174825176,
#   '1': 0.087412587412588,
#   '2': 0.10664335664335377,
#   '3': 0.087412587412588,
#   '4': 0.174825174825176,
#   '5': 0.087412587412588,
#   '6': 0.087412587412588,
#   '7': 0.087412587412588,
#   '8': 0.10664335664335425,
#   '9': 0.087412587412588,
#   '10': 0.087412587412588,
#   'text': 'Mark Zuckerbergs data was collected by third parties https://t.co/92BIPhwtdG https://t.co/qNNkI52geE'},
#  {'0': 0.19405594405594234,
#   '1': 0.08741258741258799,
#   '2': 0.08741258741258799,
#   '3': 0.08832671781009571,
#   '4': 0.19405594405594234,
#   '5': 0.08741258741258799,
#   '6': 0.08741258741258799,
#   '7': 0.08741258741258799,
#   '8': 0.08741258741258799,
#   '9': 0.10572922624584598,
#   '10': 0.08741258741258799,
#   'text': 'KOOL-MOSING-ALONGKOOL-MO-&amp;-Huey Lewis &amp; The NewsSingsThe Power Of Love4The Duke and Duchess of Camb https://t.co/vo5uITyzol'},
#  {'0': 0.1940559440559413,
#   '1': 0.08741258741258798,
#   '2': 0.08741258741258798,
#   '3': 0.10664335664335482,
#   '4': 0.1940559440559413,
#   '5': 0.08741258741258798,
#   '6': 0.08741258741258798,
#   '7': 0.08741258741258798,
#   '8': 0.08741258741258798,
#   '9': 0.08741258741258798,
#   '10': 0.08741258741258798,
#   'text': 'Another #dating #service - do we really need #Facebook to do this to us ?\n\n#JMKWednesday #JMK_Wednesday https://t.co/bJRuGBhzRo'},
#  {'0': 0.19421312252196554,
#   '1': 0.08741258741258796,
#   '2': 0.08741258741258796,
#   '3': 0.08742344780196896,
#   '4': 0.19421312252196554,
#   '5': 0.08741258741258796,
#   '6': 0.08741258741258796,
#   '7': 0.08741258741258796,
#   '8': 0.0910682392992152,
#   '9': 0.08741258741258796,
#   '10': 0.10281966590132254,
#   'text': 'Great to see updates like this happening, about time too!  #facebook #digitalmarketing\nhttps://t.co/4GRwAdiOkV'},
#  {'0': 0.17482517482517582,
#   '1': 0.08741258741258791,
#   '2': 0.08741258741258791,
#   '3': 0.1066433566433518,
#   '4': 0.17482517482517582,
#   '5': 0.08741258741258791,
#   '6': 0.1066433566433569,
#   '7': 0.08741258741258791,
#   '8': 0.08741258741258791,
#   '9': 0.08741258741258791,
#   '10': 0.08741258741258791,
#   'text': 'Take the #SQL headache out of your #BigData project. Use  Kognitio #hadoop #bigdata #mapr #inmemory #MPP https://t.co/vzDJdjUhxf'},
#  {'0': 0.19405594405594376,
#   '1': 0.08741258741258788,
#   '2': 0.08742355577513998,
#   '3': 0.08941143459132497,
#   '4': 0.19405594405594376,
#   '5': 0.09135340845394402,
#   '6': 0.08741258741258788,
#   '7': 0.08741258741258788,
#   '8': 0.08741258741258788,
#   '9': 0.08741258741258788,
#   '10': 0.10069272006070785,
#   'text': 'THANK YOU PART 1 OF 2\n300 FOLLOWS FACEBOOK\n300 SUBS YOUTUBE\n\n#Youtube #Facebook #Subs https://t.co/TImcIPvG67'},
#  {'0': 0.1748251748251757,
#   '1': 0.08741258741258785,
#   '2': 0.10663349084631611,
#   '3': 0.08741258741258785,
#   '4': 0.1748251748251757,
#   '5': 0.1066433566433526,
#   '6': 0.08741258741258785,
#   '7': 0.0874224532096285,
#   '8': 0.08741258741258785,
#   '9': 0.08741258741258785,
#   '10': 0.08741258741258785,
#   'text': "It's the big #zuckerberg speaks in front of #Congress #Facebook #bingo! #MarkZuckerberg #CambridgeAnalytics https://t.co/zreoivY1xI"},
#  {'0': 0.1748251748251756,
#   '1': 0.0874125874125878,
#   '2': 0.10664335664335352,
#   '3': 0.0874125874125878,
#   '4': 0.1748251748251756,
#   '5': 0.10664335664335615,
#   '6': 0.0874125874125878,
#   '7': 0.0874125874125878,
#   '8': 0.0874125874125878,
#   '9': 0.0874125874125878,
#   '10': 0.0874125874125878,
#   'text': 'Hard Questions: What Data Does Facebook Collect When Im Not Using Facebook, and Why? | https://t.co/leCzRQ4Jbl'},
#  {'0': 0.18747491214981832,
#   '1': 0.0874125874125878,
#   '2': 0.0939936193187132,
#   '3': 0.0874125874125878,
#   '4': 0.18747491214981832,
#   '5': 0.0874125874125878,
#   '6': 0.0874125874125878,
#   '7': 0.0874125874125878,
#   '8': 0.0874125874125878,
#   '9': 0.0874125874125878,
#   '10': 0.10664335664335403,
#   'text': 'Thats a lot of Zuckerberg shares. https://t.co/K1J7GNbXJQ'},
#  {'0': 0.17482517482517557,
#   '1': 0.08741258741258778,
#   '2': 0.08741258741258778,
#   '3': 0.08741258741258778,
#   '4': 0.17482517482517557,
#   '5': 0.08741258741258778,
#   '6': 0.12587412587412217,
#   '7': 0.08741258741258778,
#   '8': 0.08741258741258778,
#   '9': 0.08741258741258778,
#   '10': 0.08741258741258778,
#   'text': "Richmond's Information Science Daily! https://t.co/DMKFCnHDPM #machinelearning #bigdata"},
#  {'0': 0.17482517482517557,
#   '1': 0.08741258741258778,
#   '2': 0.08741258741258778,
#   '3': 0.08741258741258778,
#   '4': 0.17482517482517557,
#   '5': 0.1258741258741221,
#   '6': 0.08741258741258778,
#   '7': 0.08741258741258778,
#   '8': 0.08741258741258778,
#   '9': 0.08741258741258778,
#   '10': 0.08741258741258778,
#   'text': 'Hear, hear  https://t.co/7cVqSAqNRK'},
#  {'0': 0.20603207394002393,
#   '1': 0.08741258741258776,
#   '2': 0.08741258741258776,
#   '3': 0.08741258741258776,
#   '4': 0.20603207394002393,
#   '5': 0.08741258741258776,
#   '6': 0.08741258741258776,
#   '7': 0.094667226759274,
#   '8': 0.08741258741258776,
#   '9': 0.08741258741258776,
#   '10': 0.08741258741258776,
#   'text': 'Facebook annonce le dating sur son app ! Quand Facebook copie Tinder ! #F8 #Facebook'},
#  {'0': 0.1748251748251755,
#   '1': 0.08741258741258776,
#   '2': 0.08741258741258776,
#   '3': 0.08741258741258776,
#   '4': 0.1748251748251755,
#   '5': 0.08741258741258776,
#   '6': 0.10664335664335452,
#   '7': 0.08741258741258776,
#   '8': 0.08741258741258776,
#   '9': 0.10547959241253568,
#   '10': 0.08857635164340781,
#   'text': 'So many things to learn!!! https://t.co/0qeHv6A0B1'},
#  {'0': 0.17482517482517546,
#   '1': 0.08741258741258773,
#   '2': 0.08741258741258773,
#   '3': 0.08741860938883686,
#   '4': 0.17482517482517546,
#   '5': 0.10804476827941302,
#   '6': 0.08741258741258773,
#   '7': 0.0874187417719773,
#   '8': 0.08741258741258773,
#   '9': 0.08741258741258773,
#   '10': 0.10522976867165867,
#   'text': '@BBCJonSopel Substitute Zuckerberg for Pep Guardiola - the answers would be great.'},
#  {'0': 0.17482517482517543,
#   '1': 0.08741258741258771,
#   '2': 0.125874125874123,
#   '3': 0.08741258741258771,
#   '4': 0.17482517482517543,
#   '5': 0.08741258741258771,
#   '6': 0.08741258741258771,
#   '7': 0.08741258741258771,
#   '8': 0.08741258741258771,
#   '9': 0.08741258741258771,
#   '10': 0.08741258741258771,
#   'text': 'Facebook moving most users from protection of EU privacy law  Silicon Valley https://t.co/jWSUHDZTZW'},
#  {'0': 0.17482517482517537,
#   '1': 0.08741258741258769,
#   '2': 0.08741258741258769,
#   '3': 0.08741258741258769,
#   '4': 0.17482517482517537,
#   '5': 0.09865735712519011,
#   '6': 0.08741258741258769,
#   '7': 0.11462266922791921,
#   '8': 0.08741927434618921,
#   '9': 0.08741258741258769,
#   '10': 0.08741258741258769,
#   'text': '#Facebook #Zuckerberg  is in #Paris - already faced EU committee over Data scandal. https://t.co/3IBYLS2Vap'},
#  {'0': 0.1940559440559424,
#   '1': 0.08741258741258769,
#   '2': 0.08741258741258769,
#   '3': 0.08741258741258769,
#   '4': 0.1940559440559424,
#   '5': 0.10664335664335602,
#   '6': 0.08741258741258769,
#   '7': 0.08741258741258769,
#   '8': 0.08741258741258769,
#   '9': 0.08741258741258769,
#   '10': 0.08741258741258769,
#   'text': 'Wat een heerlijke video: These are the most confusing questions Congress asked Zuckerberg https://t.co/z4TFbossuX'},
#  {'0': 0.17482517482517526,
#   '1': 0.1258741258741237,
#   '2': 0.08741258741258763,
#   '3': 0.08741258741258763,
#   '4': 0.17482517482517526,
#   '5': 0.08741258741258763,
#   '6': 0.08741258741258763,
#   '7': 0.08741258741258763,
#   '8': 0.08741258741258763,
#   '9': 0.08741258741258763,
#   '10': 0.08741258741258763,
#   'text': 'Robert Mercer, Steve Bannon, Donald Trump, Nigel Farage, Jacob Rees Mogg, Michael Gove, Cambridge Analytica, Vote L https://t.co/5gJwzJBcrm'},
#  {'0': 0.17482517482517518,
#   '1': 0.08741258741258759,
#   '2': 0.125825715512047,
#   '3': 0.08741258741258759,
#   '4': 0.17482517482517518,
#   '5': 0.08741258741258759,
#   '6': 0.08741258741258759,
#   '7': 0.0874208282279348,
#   '8': 0.08741258741258759,
#   '9': 0.08741258741258759,
#   '10': 0.08745275695931747,
#   'text': 'Privacy Information https://t.co/An1a3aDxVS'},
#  {'0': 0.17482517482517518,
#   '1': 0.08741258741258759,
#   '2': 0.08741258741258759,
#   '3': 0.08741258741258759,
#   '4': 0.17482517482517518,
#   '5': 0.08741258741258759,
#   '6': 0.12587412587412408,
#   '7': 0.08741258741258759,
#   '8': 0.08741258741258759,
#   '9': 0.08741258741258759,
#   '10': 0.08741258741258759,
#   'text': 'The latest Analytics Network Daily Roundup! https://t.co/IQqVScFn2w Thanks to @FlyingBinary #meltdown #microsoft'},
#  {'0': 0.17482517482517504,
#   '1': 0.08741258741258752,
#   '2': 0.08741258741258752,
#   '3': 0.08741258741258752,
#   '4': 0.17482517482517504,
#   '5': 0.08741258741258752,
#   '6': 0.12587412587412483,
#   '7': 0.08741258741258752,
#   '8': 0.08741258741258752,
#   '9': 0.08741258741258752,
#   '10': 0.08741258741258752,
#   'text': 'The latest  Karl Ffrench - Daily ! https://t.co/h50k9ZQiRN Thanks to @raimeygallant #bigdata #datascience'},
#  {'0': 0.17715523066531474,
#   '1': 0.0797448165869485,
#   '2': 0.0797448165869485,
#   '3': 0.09781310973769625,
#   '4': 0.17715523066531474,
#   '5': 0.08850385588905971,
#   '6': 0.11429485098826157,
#   '7': 0.08727044543089008,
#   '8': 0.09727167895841346,
#   '9': 0.0809125189206956,
#   '10': 0.09728867623577157,
#   'text': 'Digital marketing is an investment. It takes time to mature before it can pay you back. #facebook https://t.co/BJvLD5JZsJ'},
#  {'0': 0.1721959096656846,
#   '1': 0.0833756887573752,
#   '2': 0.1082782874460103,
#   '3': 0.09628837064219813,
#   '4': 0.1721959096656846,
#   '5': 0.07575757575758044,
#   '6': 0.07575757575758044,
#   '7': 0.09094358224742409,
#   '8': 0.0924242424242429,
#   '9': 0.10242652900730662,
#   '10': 0.10255223829459728,
#   'text': 'the entire purpose of #Facebook is to make #money by treating its #users as the #product that it sells to https://t.co/lpg5diRH2d'},
#  ...]

# %%
#el elemento de relevant documents,es el que corresponde, ahora veamos el tinfo_collection_1


#data['relevantDocumentsDict_new'] == topicvisexplorer.single_corpus_data['relevantDocumentsDict']
# Out:
# c:\users\gonza\tesisenv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# False

# %%
 topicvisexplorer.single_corpus_data.keys()
# Out:
# c:\users\gonza\tesisenv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# dict_keys(['data_dict', 'PreparedDataObtained', 'relevantDocumentsDict', 'word_embedding_model', 'tinfo_collection', 'topkeywords_vectors_dict', 'relevantdocuments_vectors_dict', 'lda_model', 'corpus', 'id2word', 'topic_similarity_matrix', 'topic.order', 'new_circle_positions'])

# %%
 topicvisexplorer.single_corpus_data['tinfo_collection']
# Out:
# c:\users\gonza\tesisenv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        Category     Freq          Term         Total  loglift  logprob  \
# 0       Default  32493.0        remove  32493.000000  17303.0  17303.0
# 1       Default  30097.0          link  30097.000000  17302.0  17302.0
# 2       Default   5002.0         datum   5002.000000  17301.0  17301.0
# 3       Default   3701.0       bigdata   3701.000000  17300.0  17300.0
# 4       Default   4989.0      facebook   4989.000000  17299.0  17299.0
# ...         ...      ...           ...           ...      ...      ...
# 207631  Topic11      0.0          mest      1.148572     -inf     -inf
# 207632  Topic11      0.0     premature      1.147959     -inf     -inf
# 207633  Topic11      0.0  consolidator      1.131308     -inf     -inf
# 207634  Topic11      0.0       jetpack      1.131308     -inf     -inf
# 207635  Topic11      0.0      unionise      1.148572     -inf     -inf
#
#         relevance
# 0         17303.0
# 1         17302.0
# 2         17301.0
# 3         17300.0
# 4         17299.0
# ...           ...
# 207631       -inf
# 207632       -inf
# 207633       -inf
# 207634       -inf
# 207635       -inf
#
# [207636 rows x 7 columns]

# %%
topicvisexplorer.single_corpus_data.keys()
# Out:
# c:\users\gonza\tesisenv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# dict_keys(['data_dict', 'PreparedDataObtained', 'relevantDocumentsDict', 'word_embedding_model', 'tinfo_collection', 'topkeywords_vectors_dict', 'relevantdocuments_vectors_dict', 'lda_model', 'corpus', 'id2word', 'topic_similarity_matrix', 'topic.order', 'new_circle_positions'])

# %%
pd.DataFrame(data['lamData_new'])
# Out:
# c:\users\gonza\tesisenv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        Category     Freq          Term         Total  loglift  logprob  \
# 0       Default  19023.0         datum  19023.000000  31977.0  31977.0
# 1       Default  10705.0       bigdata  10705.000000  31976.0  31976.0
# 2       Default   8660.0       privacy   8660.000000  31975.0  31975.0
# 3       Default   9296.0      facebook   9296.000000  31974.0  31974.0
# 4       Default   6147.0          user   6147.000000  31973.0  31973.0
# ...         ...      ...           ...           ...      ...      ...
# 383719  Topic11      0.0     riskblock      1.229759      NaN      NaN
# 383720  Topic11      0.0   thirdpartie      1.103186      NaN      NaN
# 383721  Topic11      0.0  netcommfocus      1.231039      NaN      NaN
# 383722  Topic11      0.0    sharmishta      1.216717      NaN      NaN
# 383723  Topic11      0.0    adulteress      1.231039      NaN      NaN
#
#         relevance
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 383719        NaN
# 383720        NaN
# 383721        NaN
# 383722        NaN
# 383723        NaN
#
# [383724 rows x 7 columns]

# %%
type(topicvisexplorer.single_corpus_data['PreparedDataObtained']['tinfo'])
#single_corpus_data['tinfo_collection']
# Out:
# c:\users\gonza\tesisenv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# dict

# %%
pd.DataFrame(data['lamData_new']).to_dict().keys()
# Out:
# c:\users\gonza\tesisenv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# dict_keys(['Category', 'Freq', 'Term', 'Total', 'loglift', 'logprob', 'relevance'])

# %%
topicvisexplorer.single_corpus_data['PreparedDataObtained']['tinfo'].keys()
# Out:
# c:\users\gonza\tesisenv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# dict_keys(['Category', 'Freq', 'Term', 'Total', 'loglift', 'logprob'])

# %%
matrix_documents_topic_contribution = pd.DataFrame(topicvisexplorer.single_corpus_data['relevantDocumentsDict'])
# Out:
# c:\users\gonza\tesisenv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
matrix_documents_topic_contribution
# Out:
# c:\users\gonza\tesisenv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#              0         1         2         3         4         5         6  \
# 0     0.271680  0.077370  0.088134  0.089595  0.074516  0.271680  0.074516
# 1     0.267684  0.095661  0.080997  0.085200  0.075193  0.267684  0.067843
# 2     0.261332  0.090858  0.090861  0.084141  0.074516  0.261332  0.074516
# 3     0.246225  0.091873  0.077171  0.091449  0.077042  0.246225  0.077042
# 4     0.233722  0.103845  0.092980  0.081194  0.074631  0.233722  0.075967
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995  0.144205  0.123782  0.093485  0.076214  0.072076  0.144205  0.101511
# 1996  0.133877  0.171820  0.122522  0.065876  0.106874  0.133877  0.080369
# 1997  0.143506  0.111664  0.109906  0.065876  0.122848  0.143506  0.098160
# 1998  0.131808  0.065907  0.065876  0.100713  0.172247  0.131808  0.065876
# 1999  0.124533  0.157171  0.062267  0.062334  0.107502  0.124533  0.109011
#
#              7         8         9        10  \
# 0     0.075407  0.083358  0.089876  0.075549
# 1     0.105179  0.084788  0.067843  0.069613
# 2     0.074566  0.083736  0.074516  0.090957
# 3     0.077042  0.091124  0.093991  0.077042
# 4     0.074516  0.081327  0.107303  0.074516
# ...        ...       ...       ...       ...
# 1995  0.122595  0.076792  0.082387  0.106953
# 1996  0.080369  0.092048  0.080369  0.065876
# 1997  0.098354  0.093680  0.065876  0.090129
# 1998  0.156410  0.065876  0.065876  0.109411
# 1999  0.115843  0.068535  0.108950  0.083855
#
#                                          texto_completo
# 0     Happy #Friday Click here to join in the #Frida...
# 1     Introducing a brand new tournament series for ...
# 2     This strategy made our cost per page like just...
# 3     Using Facebook Custom Audiences to increase sa...
# 4     Product #marketing #manager, Global Video Adve...
# ...                                                 ...
# 1995  Domestic &amp; Business Utilities \n\nQuote Sp...
# 1996  <usernameremoved> <usernameremoved> There shou...
# 1997  always makes me laugh when middle aged women s...
# 1998  Fellow countrymen, lend me your ears or eyes. ...
# 1999  #BigData problem\n\nRunning ten 2-level logit ...
#
# [2000 rows x 12 columns]

# %%
topic_id = str(0)
topkdocuments = 20
matrix_documents_topic_contribution.sort_values(by=[topic_id], ascending=False)[[topic_id,matrix_documents_topic_contribution.columns[-1]]][0:topkdocuments].iterrows()

#matrix_documents_topic_contribution.sort_values(by=[topic_id], ascending=False)[[topic_id,matrix_documents_topic_contribution.columns[-1]]][0:topkdocuments].iterrows():
# Out:
# c:\users\gonza\tesisenv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <generator object DataFrame.iterrows at 0x000002223B0CB3C0>
