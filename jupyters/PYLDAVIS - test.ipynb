# %%
import gensim
LdaModel = gensim.models.ldamodel.LdaModel
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import pickle
from gensim.corpora import Dictionary

# %%
#lda_model_collecion_1 = LdaModel.load("../data/cambridge_analytica/regional_datasets/files_europe/english_europe_tweets_20190411.csv_gensim.model")
lda_model_collecion_1 = LdaModel.load("../data/cambridge_analytica/regional_datasets/files_northamerica/english_northamerica_tweets_20190411.csv_gensim.model")

# %%
#with open('../data/cambridge_analytica/regional_datasets/files_europe/english_europe_tweets_20190411.csv_corpus.pkl', 'rb') as f:
#    corpus = pickle.load(f)

with open('../data/cambridge_analytica/regional_datasets/files_northamerica/english_northamerica_tweets_20190411.csv_corpus.pkl', 'rb') as f:
    corpus = pickle.load(f)

# %%
#id2word = Dictionary.load("../data/cambridge_analytica/regional_datasets/files_europe/english_europe_tweets_20190411.csv_id2word")
id2word = Dictionary.load("../data/cambridge_analytica/regional_datasets/files_northamerica/english_northamerica_tweets_20190411.csv_id2word")

# %%
pyLDAvis.enable_notebook()

# %%
data = pyLDAvis.gensim.prepare(lda_model_collecion_1, corpus,id2word, mds='pcoa')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyLDAvis\_prepare.py:223: RuntimeWarning: divide by zero encountered in log
#   kernel = (topic_given_term * np.log((topic_given_term.T / topic_proportion).T))
# C:\ProgramData\Anaconda3\lib\site-packages\pyLDAvis\_prepare.py:240: RuntimeWarning: divide by zero encountered in log
#   log_lift = np.log(topic_term_dists / term_proportion)
# C:\ProgramData\Anaconda3\lib\site-packages\pyLDAvis\_prepare.py:241: RuntimeWarning: divide by zero encountered in log
#   log_ttd = np.log(topic_term_dists)

# %%
data
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster      Freq
# topic
# 4     -0.233844 -0.113942       1        1  9.171939
# 9      0.098880 -0.233418       2        1  9.147267
# 8      0.018151 -0.101167       3        1  9.136751
# 6     -0.218836 -0.097332       4        1  9.124719
# 2     -0.132280  0.085199       5        1  9.114894
# 0     -0.181707  0.086301       6        1  9.086134
# 3      0.162211 -0.122475       7        1  9.085147
# 7      0.215074 -0.118297       8        1  9.084022
# 5      0.108741  0.183699       9        1  9.056988
# 1      0.187287  0.187107      10        1  9.026366
# 10    -0.023678  0.244324      11        1  8.965775, topic_info=        Term          Freq         Total Category  logprob  loglift
# 3      datum  46443.000000  46443.000000  Default  30.0000  30.0000
# 11     trump  34999.000000  34999.000000  Default  29.0000  29.0000
# 184  privacy  27062.000000  27062.000000  Default  28.0000  28.0000
# 17    people  25097.000000  25097.000000  Default  27.0000  27.0000
# 181     make  20775.000000  20775.000000  Default  26.0000  26.0000
# ..       ...           ...           ...      ...      ...      ...
# 672      day   4913.867247   7659.081993  Topic11  -3.9329   1.9679
# 896   member   2108.903582   2609.201811  Topic11  -4.7788   2.1989
# 267    start   2789.116413   6351.640126  Topic11  -4.4993   1.5888
# 89      late   1938.240864   5518.380936  Topic11  -4.8632   1.3655
# 586  explain   1627.390914   2706.246803  Topic11  -5.0380   1.9032
#
# [797 rows x 6 columns], token_table=       Topic      Freq          Term
# term
# 22784      2  0.825508   absenteeism
# 14781     11  1.093775  academically
# 25864      1  0.845149       acauire
# 211        1  0.999986        access
# 416        3  0.999701        accord
# ...      ...       ...           ...
# 23254      5  0.884600         yhere
# 14556     11  0.996117          yoga
# 24027      4  0.962201       younger
# 10822      6  0.973867           yup
# 3336       9  1.000111          zuck
#
# [982 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[5, 10, 9, 7, 3, 1, 4, 8, 6, 2, 11])
