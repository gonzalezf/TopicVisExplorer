# %%
import pickle

# %%
with open('../data/cambridge_analytica/matrix_collection_1_1', 'rb') as f:
    matrix = pickle.load(f)

# %%
matrix
# Out:
# {0.0: array([[0.99999988, 0.95897526, 0.95427388, 0.93884087, 0.94862819,
#          0.96145672, 0.93520367, 0.97511584, 0.91672176, 0.81999826,
#          0.96460879, 0.94735825, 0.91906488, 0.95958412, 0.95121622],
#         [0.95897526, 1.00000012, 0.93673551, 0.93249989, 0.96308339,
#          0.99003297, 0.93674266, 0.96170211, 0.93864906, 0.81245267,
#          0.97206044, 0.92672867, 0.90492004, 0.97001553, 0.95655334],
#         [0.95427388, 0.93673551, 1.00000012, 0.95717347, 0.9510709 ,
#          0.94467276, 0.95086402, 0.96168733, 0.9133411 , 0.88622332,
#          0.95143306, 0.95831406, 0.8917523 , 0.94714463, 0.95283544],
#         [0.93884087, 0.93249989, 0.95717347, 0.99999976, 0.95746672,
#          0.94084871, 0.95706624, 0.93811595, 0.9034698 , 0.85053968,
#          0.94902271, 0.95217717, 0.88072902, 0.95099413, 0.96368265],
#         [0.94862819, 0.96308339, 0.9510709 , 0.95746672, 1.        ,
# ...
